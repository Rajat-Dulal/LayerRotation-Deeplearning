# %% [markdown]
# Result computation and analysis of MNIST toy experiment. Goal is to see on a toy example how layer rotation affects the features learned by a network.
#
#
# Experiment info:
#
# 1 layer MLP (784 hidden) + batchnorm (batchnorm was used to enable larger layer rotations)
# reduced MNIST dataset (1000 samples per class) (to increase overparametrization)
# Layca as optimization algorithm
# different initial learning rates

# %%
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %load_ext autoreload

# %%
# %autoreload
import sys
sys.path.insert(0, "../")

import warnings
import os
import time

import math as m
import numpy as np
np.random.seed(1)

import matplotlib
import matplotlib.pyplot as plt
import pickle

from keras.layers import Input, Dense, BatchNormalization, Activation
from keras.models import Model
from layca_optimizers import SGD
from keras.callbacks import LearningRateScheduler

from experiment_utils import plot_history, history_todict
from layer_rotation_utils import LayerRotationCurves, plot_layer_rotation_curves
from experiment_utils import lr_schedule

from feature_visualization import visualize_1stlayer_weights
from utils import load_reduced_mnist_data
# Out:
# Using TensorFlow backend.
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:469: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:470: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:471: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:472: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:473: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:476: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# utilities for storing the results in pickle files
result_file = 'results_cifar_1.p'
def load_results():
    if not os.path.isfile(result_file):
        return {}
    else:
        with open(result_file,'rb') as f:
            return pickle.load(f)

def dump_results(results):
    with open(result_file,'wb') as f:
        pickle.dump(dict(results),f)

def update_results(path, new_data):
    results = load_results()
    position = results
    for p in path:
        position = position[p]
    # new_data is a dictionary with the new (key,value) pairs
    position.update(new_data)
    dump_results(results)
    
# if results should be saved in the file or not
save_results = True
if not save_results:
    results = {}

# %%
# ----------------------------------
# 1. Load CIFAR-10 dataset (Reduced)
# ----------------------------------
from keras.datasets import cifar10
from keras.utils import to_categorical
from skimage.color import rgb2gray
from skimage.transform import resize


(x_train, y_train), (x_test, y_test) = cifar10.load_data()


# Reduce dataset size to make training faster
train_samples = 10000
test_samples = 10000
x_train, y_train = x_train[:train_samples], y_train[:train_samples]
x_test, y_test = x_test[:test_samples], y_test[:test_samples]

# Convert to grayscale
x_train = np.expand_dims(rgb2gray(x_train), axis=-1)  # shape: (N, 32, 32, 1)
x_test = np.expand_dims(rgb2gray(x_test), axis=-1)    # shape: (N, 32, 32, 1)

# Resize function for all images
def resize_images(images, new_shape=(28, 28)):
    return np.array([resize(image, new_shape, anti_aliasing=True) for image in images])

# Resize your grayscale images
x_train_resized = resize_images(x_train.squeeze())  # shape: (N, 28, 28)
x_test_resized = resize_images(x_test.squeeze())    # shape: (N, 28, 28)

# Flatten each image
x_train = x_train_resized.reshape((x_train_resized.shape[0], -1))  # shape: (N, 784)
x_test = x_test_resized.reshape((x_test_resized.shape[0], -1))     # shape: (N, 784)


# Flatten each image
x_train = x_train.reshape((x_train.shape[0], -1))  # shape: (N, 32 * 32 * 3)
x_test = x_test.reshape((x_test.shape[0], -1))     # shape: (N, 32 * 32 * 3)


# Normalize data
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.


# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (10000, 784)
# (10000, 10)

# %%
def get_model():
    inp = Input((784,))
    x = Dense(784, activation = 'linear', name = 'dense0')(inp)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dense(10, activation = 'softmax', name = 'densef')(x)
    return Model(inp,x)

# %%
os.makedirs('saved_weights_cifar1', exist_ok=True)

# %%
# !pip install h5py==2.10.0

# %%
import h5py
print(h5py.__version__)  # should print 2.10.0
# Out:
# 2.10.0

# %%
# configuration of the different learning rate schedules 
# (a division of the learning rate by 5 is used to escape plateaus in the loss curve)
training_configs = {3**-2: (100, LearningRateScheduler(lr_schedule(3**-2,1./5.,[90]))),
                    3**-2.5: (100, LearningRateScheduler(lr_schedule(3**-2.5,1./5.,[95]))),
                    3**-3: (100, LearningRateScheduler(lr_schedule(3**-3,1./5.,[95]))),
                    3**-4: (100, LearningRateScheduler(lr_schedule(3**-4,1.,[np.inf]))),
                    3**-5: (120, LearningRateScheduler(lr_schedule(3**-5,1.,[np.inf]))),
                    3**-6: (300, LearningRateScheduler(lr_schedule(3**-6,1.,[np.inf]))),
                    3**-7: (1000, LearningRateScheduler(lr_schedule(3**-7,1.,[np.inf])))}

lrs = [3**-2,3**-3,3**-4, 3**-5]
for lr in lrs:
    model = get_model()

    weights_location = 'saved_weights_cifar1/cifar_initial_weights.h5'
    if not os.path.isfile(weights_location):
        model.save_weights(weights_location)
    else:
        model.load_weights(weights_location)

    epochs = training_configs[lr][0]
    lr_sched = training_configs[lr][1]

    ladc = LayerRotationCurves(batch_frequency = np.inf)

    model.compile(loss='categorical_crossentropy',
                  optimizer=SGD(lr,layca = True),
                  metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                        batch_size=2048,
                        epochs=epochs,
                        verbose=1,
                        validation_data = (x_test,y_test),
                        callbacks = [ladc, lr_sched])


    if save_results:
        update_results([],{lr:{'history':history_todict(history),'ladc':ladc.memory}})
    else:
        results.update({lr:{'history':history_todict(history),'ladc':ladc.memory}})

    if save_results:
        model.save_weights('saved_weights_cifar1/'+str(round(lr,6))[2:]+'.h5')
# Out:
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 2.1696 - acc: 0.2117 - val_loss: 2.2943 - val_acc: 0.1029
# Epoch 2/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 2.0481 - acc: 0.2681 - val_loss: 2.2882 - val_acc: 0.1716
# Epoch 3/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.9918 - acc: 0.2940 - val_loss: 2.2829 - val_acc: 0.1227
# Epoch 4/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.9692 - acc: 0.3035 - val_loss: 2.2859 - val_acc: 0.1146
# Epoch 5/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.9458 - acc: 0.3159 - val_loss: 2.2823 - val_acc: 0.1975
# Epoch 6/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.9267 - acc: 0.3219 - val_loss: 2.2783 - val_acc: 0.1230
# Epoch 7/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.9048 - acc: 0.3226 - val_loss: 2.2765 - val_acc: 0.2359
# Epoch 8/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8968 - acc: 0.3314 - val_loss: 2.2802 - val_acc: 0.1321
# Epoch 9/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8885 - acc: 0.3364 - val_loss: 2.2780 - val_acc: 0.2063
# Epoch 10/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8779 - acc: 0.3392 - val_loss: 2.2759 - val_acc: 0.1373
# Epoch 11/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8816 - acc: 0.3350 - val_loss: 2.2756 - val_acc: 0.2312
# Epoch 12/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8690 - acc: 0.3421 - val_loss: 2.2705 - val_acc: 0.1897
# Epoch 13/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8712 - acc: 0.3403 - val_loss: 2.2756 - val_acc: 0.2252
# Epoch 14/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8681 - acc: 0.3456 - val_loss: 2.2703 - val_acc: 0.1731
# Epoch 15/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8598 - acc: 0.3432 - val_loss: 2.2735 - val_acc: 0.2241
# Epoch 16/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8587 - acc: 0.3495 - val_loss: 2.2681 - val_acc: 0.1947
# Epoch 17/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8502 - acc: 0.3515 - val_loss: 2.2731 - val_acc: 0.2083
# Epoch 18/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8471 - acc: 0.3528 - val_loss: 2.2676 - val_acc: 0.2714
# Epoch 19/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8571 - acc: 0.3442 - val_loss: 2.2704 - val_acc: 0.1637
# Epoch 20/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8509 - acc: 0.3439 - val_loss: 2.2710 - val_acc: 0.2373
# Epoch 21/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8512 - acc: 0.3518 - val_loss: 2.2623 - val_acc: 0.2039
# Epoch 22/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8468 - acc: 0.3526 - val_loss: 2.2647 - val_acc: 0.2282
# Epoch 23/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8460 - acc: 0.3532 - val_loss: 2.2570 - val_acc: 0.2431
# Epoch 24/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8511 - acc: 0.3486 - val_loss: 2.2644 - val_acc: 0.2344
# Epoch 25/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8485 - acc: 0.3480 - val_loss: 2.2624 - val_acc: 0.2185
# Epoch 26/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8498 - acc: 0.3454 - val_loss: 2.2626 - val_acc: 0.2401
# Epoch 27/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8432 - acc: 0.3591 - val_loss: 2.2539 - val_acc: 0.2496
# Epoch 28/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8475 - acc: 0.3505 - val_loss: 2.2609 - val_acc: 0.2613
# Epoch 29/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8406 - acc: 0.3575 - val_loss: 2.2573 - val_acc: 0.2489
# Epoch 30/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8376 - acc: 0.3589 - val_loss: 2.2586 - val_acc: 0.2278
# Epoch 31/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8427 - acc: 0.3562 - val_loss: 2.2488 - val_acc: 0.2182
# Epoch 32/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8462 - acc: 0.3486 - val_loss: 2.2577 - val_acc: 0.2455
# Epoch 33/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8400 - acc: 0.3537 - val_loss: 2.2455 - val_acc: 0.2592
# Epoch 34/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8458 - acc: 0.3470 - val_loss: 2.2547 - val_acc: 0.2131
# Epoch 35/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8335 - acc: 0.3618 - val_loss: 2.2431 - val_acc: 0.2202
# Epoch 36/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8433 - acc: 0.3554 - val_loss: 2.2518 - val_acc: 0.2501
# Epoch 37/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8398 - acc: 0.3569 - val_loss: 2.2463 - val_acc: 0.2468
# Epoch 38/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8330 - acc: 0.3546 - val_loss: 2.2478 - val_acc: 0.2409
# Epoch 39/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8383 - acc: 0.3643 - val_loss: 2.2367 - val_acc: 0.2705
# Epoch 40/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8423 - acc: 0.3563 - val_loss: 2.2478 - val_acc: 0.2470
# Epoch 41/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8394 - acc: 0.3583 - val_loss: 2.2395 - val_acc: 0.2457
# Epoch 42/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8405 - acc: 0.3565 - val_loss: 2.2459 - val_acc: 0.2760
# Epoch 43/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8411 - acc: 0.3502 - val_loss: 2.2359 - val_acc: 0.2511
# Epoch 44/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8413 - acc: 0.3538 - val_loss: 2.2409 - val_acc: 0.2752
# Epoch 45/100
# 10000/10000 [==============================] - 0s 42us/step - loss: 1.8412 - acc: 0.3542 - val_loss: 2.2339 - val_acc: 0.2532
# Epoch 46/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8359 - acc: 0.3582 - val_loss: 2.2354 - val_acc: 0.2582
# Epoch 47/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8461 - acc: 0.3571 - val_loss: 2.2249 - val_acc: 0.2459
# Epoch 48/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8369 - acc: 0.3619 - val_loss: 2.2369 - val_acc: 0.2523
# Epoch 49/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8393 - acc: 0.3590 - val_loss: 2.2306 - val_acc: 0.2703
# Epoch 50/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8429 - acc: 0.3541 - val_loss: 2.2183 - val_acc: 0.2691
# Epoch 51/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8454 - acc: 0.3588 - val_loss: 2.2346 - val_acc: 0.2314
# Epoch 52/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8356 - acc: 0.3607 - val_loss: 2.2196 - val_acc: 0.2503
# Epoch 53/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8349 - acc: 0.3583 - val_loss: 2.2255 - val_acc: 0.2534
# Epoch 54/100
# 10000/10000 [==============================] - 1s 50us/step - loss: 1.8369 - acc: 0.3526 - val_loss: 2.2222 - val_acc: 0.2766
# Epoch 55/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8380 - acc: 0.3563 - val_loss: 2.2109 - val_acc: 0.2768
# Epoch 56/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8408 - acc: 0.3538 - val_loss: 2.2306 - val_acc: 0.2088
# Epoch 57/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.8362 - acc: 0.3565 - val_loss: 2.2151 - val_acc: 0.2450
# Epoch 58/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.8338 - acc: 0.3635 - val_loss: 2.2081 - val_acc: 0.2706
# Epoch 59/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8347 - acc: 0.3556 - val_loss: 2.2203 - val_acc: 0.2307
# Epoch 60/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8438 - acc: 0.3566 - val_loss: 2.2080 - val_acc: 0.2848
# Epoch 61/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8358 - acc: 0.3602 - val_loss: 2.2155 - val_acc: 0.2084
# Epoch 62/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8369 - acc: 0.3560 - val_loss: 2.1951 - val_acc: 0.2563
# Epoch 63/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8402 - acc: 0.3544 - val_loss: 2.2055 - val_acc: 0.2739
# Epoch 64/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8410 - acc: 0.3513 - val_loss: 2.2165 - val_acc: 0.2375
# Epoch 65/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8395 - acc: 0.3566 - val_loss: 2.1932 - val_acc: 0.2547
# Epoch 66/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8360 - acc: 0.3539 - val_loss: 2.2089 - val_acc: 0.2689
# Epoch 67/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8341 - acc: 0.3598 - val_loss: 2.1879 - val_acc: 0.2402
# Epoch 68/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8381 - acc: 0.3607 - val_loss: 2.1932 - val_acc: 0.2556
# Epoch 69/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.8331 - acc: 0.3608 - val_loss: 2.1977 - val_acc: 0.2667
# Epoch 70/100
# 10000/10000 [==============================] - 1s 50us/step - loss: 1.8340 - acc: 0.3598 - val_loss: 2.1851 - val_acc: 0.2690
# Epoch 71/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8370 - acc: 0.3509 - val_loss: 2.1960 - val_acc: 0.2323
# Epoch 72/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8406 - acc: 0.3500 - val_loss: 2.1839 - val_acc: 0.2595
# Epoch 73/100
# 10000/10000 [==============================] - 1s 53us/step - loss: 1.8322 - acc: 0.3567 - val_loss: 2.1763 - val_acc: 0.3058
# Epoch 74/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.8338 - acc: 0.3634 - val_loss: 2.1751 - val_acc: 0.2809
# Epoch 75/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8374 - acc: 0.3563 - val_loss: 2.1952 - val_acc: 0.2134
# Epoch 76/100
# 10000/10000 [==============================] - 1s 50us/step - loss: 1.8340 - acc: 0.3642 - val_loss: 2.1629 - val_acc: 0.2734
# Epoch 77/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8334 - acc: 0.3581 - val_loss: 2.1810 - val_acc: 0.2418
# Epoch 78/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.8354 - acc: 0.3580 - val_loss: 2.1608 - val_acc: 0.2686
# Epoch 79/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8351 - acc: 0.3544 - val_loss: 2.1773 - val_acc: 0.2346
# Epoch 80/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8366 - acc: 0.3523 - val_loss: 2.1733 - val_acc: 0.2638
# Epoch 81/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8381 - acc: 0.3610 - val_loss: 2.1709 - val_acc: 0.2039
# Epoch 82/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8383 - acc: 0.3556 - val_loss: 2.1760 - val_acc: 0.2329
# Epoch 83/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8390 - acc: 0.3587 - val_loss: 2.1467 - val_acc: 0.2452
# Epoch 84/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8400 - acc: 0.3526 - val_loss: 2.1718 - val_acc: 0.2475
# Epoch 85/100
# 10000/10000 [==============================] - 1s 55us/step - loss: 1.8403 - acc: 0.3562 - val_loss: 2.1416 - val_acc: 0.2345
# Epoch 86/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 1.8249 - acc: 0.3692 - val_loss: 2.1427 - val_acc: 0.2613
# Epoch 87/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 1.8394 - acc: 0.3555 - val_loss: 2.1658 - val_acc: 0.2386
# Epoch 88/100
# 10000/10000 [==============================] - 1s 53us/step - loss: 1.8409 - acc: 0.3594 - val_loss: 2.1457 - val_acc: 0.2460
# Epoch 89/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.8364 - acc: 0.3565 - val_loss: 2.1479 - val_acc: 0.2595
# Epoch 90/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8328 - acc: 0.3592 - val_loss: 2.1289 - val_acc: 0.2734
# Epoch 91/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8008 - acc: 0.3849 - val_loss: 2.0930 - val_acc: 0.3325
# Epoch 92/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7900 - acc: 0.3865 - val_loss: 2.0923 - val_acc: 0.3488
# Epoch 93/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7892 - acc: 0.3899 - val_loss: 2.0851 - val_acc: 0.3359
# Epoch 94/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7899 - acc: 0.3878 - val_loss: 2.0841 - val_acc: 0.3387
# Epoch 95/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7885 - acc: 0.3856 - val_loss: 2.0782 - val_acc: 0.3364
# Epoch 96/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7883 - acc: 0.3886 - val_loss: 2.0802 - val_acc: 0.3474
# Epoch 97/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.7879 - acc: 0.3903 - val_loss: 2.0700 - val_acc: 0.3459
# Epoch 98/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7880 - acc: 0.3907 - val_loss: 2.0685 - val_acc: 0.3408
# Epoch 99/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7877 - acc: 0.3911 - val_loss: 2.0657 - val_acc: 0.3414
# Epoch 100/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7877 - acc: 0.3876 - val_loss: 2.0592 - val_acc: 0.3441
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 2.2252 - acc: 0.2027 - val_loss: 2.2952 - val_acc: 0.1037
# Epoch 2/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 2.0951 - acc: 0.2653 - val_loss: 2.2900 - val_acc: 0.1121
# Epoch 3/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 2.0307 - acc: 0.2813 - val_loss: 2.2863 - val_acc: 0.1159
# Epoch 4/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.9906 - acc: 0.3007 - val_loss: 2.2853 - val_acc: 0.1153
# Epoch 5/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.9614 - acc: 0.3143 - val_loss: 2.2829 - val_acc: 0.1287
# Epoch 6/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.9397 - acc: 0.3188 - val_loss: 2.2803 - val_acc: 0.1700
# Epoch 7/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.9231 - acc: 0.3262 - val_loss: 2.2789 - val_acc: 0.1578
# Epoch 8/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.9075 - acc: 0.3348 - val_loss: 2.2793 - val_acc: 0.1422
# Epoch 9/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8957 - acc: 0.3374 - val_loss: 2.2773 - val_acc: 0.1603
# Epoch 10/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8857 - acc: 0.3438 - val_loss: 2.2755 - val_acc: 0.1898
# Epoch 11/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8764 - acc: 0.3453 - val_loss: 2.2740 - val_acc: 0.1995
# Epoch 12/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8668 - acc: 0.3474 - val_loss: 2.2728 - val_acc: 0.1669
# Epoch 13/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8593 - acc: 0.3507 - val_loss: 2.2718 - val_acc: 0.2207
# Epoch 14/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8538 - acc: 0.3562 - val_loss: 2.2720 - val_acc: 0.1885
# Epoch 15/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8502 - acc: 0.3535 - val_loss: 2.2689 - val_acc: 0.1859
# Epoch 16/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8449 - acc: 0.3575 - val_loss: 2.2695 - val_acc: 0.2207
# Epoch 17/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8390 - acc: 0.3624 - val_loss: 2.2662 - val_acc: 0.2252
# Epoch 18/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8354 - acc: 0.3598 - val_loss: 2.2671 - val_acc: 0.2576
# Epoch 19/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8310 - acc: 0.3612 - val_loss: 2.2663 - val_acc: 0.2584
# Epoch 20/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8273 - acc: 0.3644 - val_loss: 2.2636 - val_acc: 0.2573
# Epoch 21/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8252 - acc: 0.3629 - val_loss: 2.2653 - val_acc: 0.2612
# Epoch 22/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8219 - acc: 0.3686 - val_loss: 2.2623 - val_acc: 0.2880
# Epoch 23/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8191 - acc: 0.3709 - val_loss: 2.2615 - val_acc: 0.3081
# Epoch 24/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8184 - acc: 0.3691 - val_loss: 2.2581 - val_acc: 0.2605
# Epoch 25/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8153 - acc: 0.3686 - val_loss: 2.2583 - val_acc: 0.2486
# Epoch 26/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8136 - acc: 0.3709 - val_loss: 2.2570 - val_acc: 0.2588
# Epoch 27/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8120 - acc: 0.3723 - val_loss: 2.2563 - val_acc: 0.2681
# Epoch 28/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8114 - acc: 0.3722 - val_loss: 2.2549 - val_acc: 0.2715
# Epoch 29/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8103 - acc: 0.3730 - val_loss: 2.2546 - val_acc: 0.3178
# Epoch 30/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8067 - acc: 0.3746 - val_loss: 2.2499 - val_acc: 0.2968
# Epoch 31/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8072 - acc: 0.3761 - val_loss: 2.2498 - val_acc: 0.3091
# Epoch 32/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8063 - acc: 0.3768 - val_loss: 2.2493 - val_acc: 0.2792
# Epoch 33/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8049 - acc: 0.3730 - val_loss: 2.2492 - val_acc: 0.3179
# Epoch 34/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8071 - acc: 0.3776 - val_loss: 2.2461 - val_acc: 0.2977
# Epoch 35/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8043 - acc: 0.3767 - val_loss: 2.2450 - val_acc: 0.3204
# Epoch 36/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8034 - acc: 0.3747 - val_loss: 2.2442 - val_acc: 0.3125
# Epoch 37/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8014 - acc: 0.3768 - val_loss: 2.2408 - val_acc: 0.3120
# Epoch 38/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8009 - acc: 0.3797 - val_loss: 2.2390 - val_acc: 0.3180
# Epoch 39/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8014 - acc: 0.3768 - val_loss: 2.2406 - val_acc: 0.3328
# Epoch 40/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8004 - acc: 0.3790 - val_loss: 2.2388 - val_acc: 0.3199
# Epoch 41/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.7999 - acc: 0.3766 - val_loss: 2.2354 - val_acc: 0.3203
# Epoch 42/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7994 - acc: 0.3811 - val_loss: 2.2342 - val_acc: 0.3091
# Epoch 43/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7992 - acc: 0.3788 - val_loss: 2.2325 - val_acc: 0.3381
# Epoch 44/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7991 - acc: 0.3752 - val_loss: 2.2295 - val_acc: 0.3248
# Epoch 45/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7989 - acc: 0.3808 - val_loss: 2.2279 - val_acc: 0.3357
# Epoch 46/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.7996 - acc: 0.3812 - val_loss: 2.2259 - val_acc: 0.3350
# Epoch 47/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.7989 - acc: 0.3776 - val_loss: 2.2233 - val_acc: 0.3285
# Epoch 48/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7999 - acc: 0.3758 - val_loss: 2.2211 - val_acc: 0.3294
# Epoch 49/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7960 - acc: 0.3807 - val_loss: 2.2211 - val_acc: 0.3235
# Epoch 50/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7962 - acc: 0.3814 - val_loss: 2.2179 - val_acc: 0.3362
# Epoch 51/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7967 - acc: 0.3787 - val_loss: 2.2160 - val_acc: 0.3256
# Epoch 52/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7956 - acc: 0.3805 - val_loss: 2.2167 - val_acc: 0.3437
# Epoch 53/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.7959 - acc: 0.3809 - val_loss: 2.2125 - val_acc: 0.3356
# Epoch 54/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.7971 - acc: 0.3821 - val_loss: 2.2131 - val_acc: 0.3371
# Epoch 55/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7946 - acc: 0.3836 - val_loss: 2.2121 - val_acc: 0.3217
# Epoch 56/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7958 - acc: 0.3805 - val_loss: 2.2054 - val_acc: 0.3340
# Epoch 57/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7964 - acc: 0.3821 - val_loss: 2.2035 - val_acc: 0.3365
# Epoch 58/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7961 - acc: 0.3794 - val_loss: 2.2024 - val_acc: 0.3300
# Epoch 59/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7962 - acc: 0.3849 - val_loss: 2.1999 - val_acc: 0.3403
# Epoch 60/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7961 - acc: 0.3830 - val_loss: 2.1956 - val_acc: 0.3371
# Epoch 61/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7949 - acc: 0.3825 - val_loss: 2.1945 - val_acc: 0.3389
# Epoch 62/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7953 - acc: 0.3827 - val_loss: 2.1898 - val_acc: 0.3403
# Epoch 63/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.7949 - acc: 0.3809 - val_loss: 2.1879 - val_acc: 0.3313
# Epoch 64/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7953 - acc: 0.3845 - val_loss: 2.1912 - val_acc: 0.3265
# Epoch 65/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7959 - acc: 0.3819 - val_loss: 2.1822 - val_acc: 0.3373
# Epoch 66/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7971 - acc: 0.3792 - val_loss: 2.1824 - val_acc: 0.3429
# Epoch 67/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7947 - acc: 0.3836 - val_loss: 2.1798 - val_acc: 0.3218
# Epoch 68/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7937 - acc: 0.3801 - val_loss: 2.1776 - val_acc: 0.3423
# Epoch 69/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7930 - acc: 0.3830 - val_loss: 2.1762 - val_acc: 0.3335
# Epoch 70/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7932 - acc: 0.3853 - val_loss: 2.1688 - val_acc: 0.3345
# Epoch 71/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7943 - acc: 0.3837 - val_loss: 2.1681 - val_acc: 0.3284
# Epoch 72/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7949 - acc: 0.3819 - val_loss: 2.1654 - val_acc: 0.3464
# Epoch 73/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7948 - acc: 0.3860 - val_loss: 2.1635 - val_acc: 0.3259
# Epoch 74/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7937 - acc: 0.3820 - val_loss: 2.1602 - val_acc: 0.3365
# Epoch 75/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.7950 - acc: 0.3856 - val_loss: 2.1583 - val_acc: 0.3380
# Epoch 76/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7938 - acc: 0.3841 - val_loss: 2.1521 - val_acc: 0.3391
# Epoch 77/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7929 - acc: 0.3813 - val_loss: 2.1477 - val_acc: 0.3320
# Epoch 78/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7937 - acc: 0.3837 - val_loss: 2.1457 - val_acc: 0.3359
# Epoch 79/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7960 - acc: 0.3831 - val_loss: 2.1415 - val_acc: 0.3305
# Epoch 80/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7943 - acc: 0.3826 - val_loss: 2.1455 - val_acc: 0.3200
# Epoch 81/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7919 - acc: 0.3844 - val_loss: 2.1343 - val_acc: 0.3334
# Epoch 82/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7940 - acc: 0.3842 - val_loss: 2.1361 - val_acc: 0.3409
# Epoch 83/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7931 - acc: 0.3813 - val_loss: 2.1295 - val_acc: 0.3334
# Epoch 84/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7944 - acc: 0.3792 - val_loss: 2.1257 - val_acc: 0.3335
# Epoch 85/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7929 - acc: 0.3818 - val_loss: 2.1242 - val_acc: 0.3428
# Epoch 86/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.7930 - acc: 0.3857 - val_loss: 2.1174 - val_acc: 0.3441
# Epoch 87/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7929 - acc: 0.3854 - val_loss: 2.1223 - val_acc: 0.3496
# Epoch 88/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7930 - acc: 0.3808 - val_loss: 2.1101 - val_acc: 0.3299
# Epoch 89/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7926 - acc: 0.3788 - val_loss: 2.1026 - val_acc: 0.3308
# Epoch 90/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7930 - acc: 0.3823 - val_loss: 2.1075 - val_acc: 0.3327
# Epoch 91/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7946 - acc: 0.3851 - val_loss: 2.1005 - val_acc: 0.3287
# Epoch 92/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.7937 - acc: 0.3823 - val_loss: 2.0994 - val_acc: 0.3204
# Epoch 93/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.7916 - acc: 0.3810 - val_loss: 2.1000 - val_acc: 0.3287
# Epoch 94/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7918 - acc: 0.3819 - val_loss: 2.0866 - val_acc: 0.3141
# Epoch 95/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7922 - acc: 0.3853 - val_loss: 2.0841 - val_acc: 0.3406
# Epoch 96/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7861 - acc: 0.3853 - val_loss: 2.0744 - val_acc: 0.3537
# Epoch 97/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7839 - acc: 0.3903 - val_loss: 2.0694 - val_acc: 0.3522
# Epoch 98/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7838 - acc: 0.3893 - val_loss: 2.0660 - val_acc: 0.3527
# Epoch 99/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7835 - acc: 0.3917 - val_loss: 2.0617 - val_acc: 0.3519
# Epoch 100/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7836 - acc: 0.3882 - val_loss: 2.0576 - val_acc: 0.3514
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 2.2727 - acc: 0.1943 - val_loss: 2.3000 - val_acc: 0.1029
# Epoch 2/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.2021 - acc: 0.2468 - val_loss: 2.2972 - val_acc: 0.1025
# Epoch 3/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 2.1479 - acc: 0.2505 - val_loss: 2.2945 - val_acc: 0.1105
# Epoch 4/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 2.1086 - acc: 0.2636 - val_loss: 2.2923 - val_acc: 0.1141
# Epoch 5/100
# 10000/10000 [==============================] - 0s 43us/step - loss: 2.0777 - acc: 0.2680 - val_loss: 2.2903 - val_acc: 0.1146
# Epoch 6/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.0522 - acc: 0.2770 - val_loss: 2.2882 - val_acc: 0.1224
# Epoch 7/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 2.0311 - acc: 0.2865 - val_loss: 2.2869 - val_acc: 0.1258
# Epoch 8/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 2.0133 - acc: 0.2918 - val_loss: 2.2851 - val_acc: 0.1311
# Epoch 9/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.9983 - acc: 0.2965 - val_loss: 2.2836 - val_acc: 0.1345
# Epoch 10/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.9847 - acc: 0.3054 - val_loss: 2.2822 - val_acc: 0.1455
# Epoch 11/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.9717 - acc: 0.3073 - val_loss: 2.2808 - val_acc: 0.1589
# Epoch 12/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.9610 - acc: 0.3142 - val_loss: 2.2792 - val_acc: 0.1633
# Epoch 13/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.9515 - acc: 0.3151 - val_loss: 2.2784 - val_acc: 0.1723
# Epoch 14/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9427 - acc: 0.3187 - val_loss: 2.2765 - val_acc: 0.1770
# Epoch 15/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.9344 - acc: 0.3238 - val_loss: 2.2752 - val_acc: 0.1867
# Epoch 16/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.9263 - acc: 0.3261 - val_loss: 2.2747 - val_acc: 0.1863
# Epoch 17/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9192 - acc: 0.3307 - val_loss: 2.2732 - val_acc: 0.1854
# Epoch 18/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.9131 - acc: 0.3325 - val_loss: 2.2718 - val_acc: 0.1974
# Epoch 19/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.9066 - acc: 0.3344 - val_loss: 2.2704 - val_acc: 0.1982
# Epoch 20/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.9015 - acc: 0.3361 - val_loss: 2.2691 - val_acc: 0.2399
# Epoch 21/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8960 - acc: 0.3412 - val_loss: 2.2680 - val_acc: 0.2119
# Epoch 22/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8906 - acc: 0.3424 - val_loss: 2.2669 - val_acc: 0.2227
# Epoch 23/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8859 - acc: 0.3431 - val_loss: 2.2652 - val_acc: 0.2473
# Epoch 24/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8814 - acc: 0.3480 - val_loss: 2.2643 - val_acc: 0.2581
# Epoch 25/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.8774 - acc: 0.3469 - val_loss: 2.2629 - val_acc: 0.2492
# Epoch 26/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8734 - acc: 0.3480 - val_loss: 2.2617 - val_acc: 0.2601
# Epoch 27/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8694 - acc: 0.3507 - val_loss: 2.2600 - val_acc: 0.2681
# Epoch 28/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8659 - acc: 0.3492 - val_loss: 2.2583 - val_acc: 0.2766
# Epoch 29/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8626 - acc: 0.3511 - val_loss: 2.2575 - val_acc: 0.2693
# Epoch 30/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8592 - acc: 0.3524 - val_loss: 2.2558 - val_acc: 0.2843
# Epoch 31/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8562 - acc: 0.3552 - val_loss: 2.2545 - val_acc: 0.2798
# Epoch 32/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8536 - acc: 0.3548 - val_loss: 2.2526 - val_acc: 0.2835
# Epoch 33/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8506 - acc: 0.3583 - val_loss: 2.2518 - val_acc: 0.2831
# Epoch 34/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8480 - acc: 0.3600 - val_loss: 2.2497 - val_acc: 0.2938
# Epoch 35/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8454 - acc: 0.3591 - val_loss: 2.2486 - val_acc: 0.2998
# Epoch 36/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8429 - acc: 0.3625 - val_loss: 2.2462 - val_acc: 0.2994
# Epoch 37/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.8404 - acc: 0.3588 - val_loss: 2.2449 - val_acc: 0.3014
# Epoch 38/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8385 - acc: 0.3649 - val_loss: 2.2430 - val_acc: 0.3073
# Epoch 39/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8362 - acc: 0.3652 - val_loss: 2.2420 - val_acc: 0.3000
# Epoch 40/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8344 - acc: 0.3639 - val_loss: 2.2405 - val_acc: 0.3145
# Epoch 41/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8327 - acc: 0.3649 - val_loss: 2.2380 - val_acc: 0.3193
# Epoch 42/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8303 - acc: 0.3660 - val_loss: 2.2366 - val_acc: 0.3104
# Epoch 43/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8294 - acc: 0.3664 - val_loss: 2.2353 - val_acc: 0.3276
# Epoch 44/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8275 - acc: 0.3682 - val_loss: 2.2327 - val_acc: 0.3233
# Epoch 45/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8251 - acc: 0.3679 - val_loss: 2.2317 - val_acc: 0.3230
# Epoch 46/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8246 - acc: 0.3725 - val_loss: 2.2288 - val_acc: 0.3181
# Epoch 47/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8225 - acc: 0.3711 - val_loss: 2.2268 - val_acc: 0.3205
# Epoch 48/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8223 - acc: 0.3705 - val_loss: 2.2250 - val_acc: 0.3249
# Epoch 49/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8200 - acc: 0.3724 - val_loss: 2.2231 - val_acc: 0.3316
# Epoch 50/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8187 - acc: 0.3722 - val_loss: 2.2211 - val_acc: 0.3284
# Epoch 51/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.8173 - acc: 0.3718 - val_loss: 2.2191 - val_acc: 0.3318
# Epoch 52/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.8160 - acc: 0.3722 - val_loss: 2.2164 - val_acc: 0.3306
# Epoch 53/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8152 - acc: 0.3728 - val_loss: 2.2151 - val_acc: 0.3336
# Epoch 54/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8145 - acc: 0.3745 - val_loss: 2.2120 - val_acc: 0.3364
# Epoch 55/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8128 - acc: 0.3731 - val_loss: 2.2110 - val_acc: 0.3352
# Epoch 56/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8121 - acc: 0.3742 - val_loss: 2.2079 - val_acc: 0.3371
# Epoch 57/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8113 - acc: 0.3775 - val_loss: 2.2040 - val_acc: 0.3323
# Epoch 58/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8101 - acc: 0.3752 - val_loss: 2.2038 - val_acc: 0.3403
# Epoch 59/100
# 10000/10000 [==============================] - 1s 50us/step - loss: 1.8094 - acc: 0.3781 - val_loss: 2.2004 - val_acc: 0.3409
# Epoch 60/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.8086 - acc: 0.3759 - val_loss: 2.1982 - val_acc: 0.3288
# Epoch 61/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8079 - acc: 0.3751 - val_loss: 2.1967 - val_acc: 0.3385
# Epoch 62/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8067 - acc: 0.3783 - val_loss: 2.1919 - val_acc: 0.3392
# Epoch 63/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8061 - acc: 0.3770 - val_loss: 2.1891 - val_acc: 0.3388
# Epoch 64/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8060 - acc: 0.3770 - val_loss: 2.1876 - val_acc: 0.3428
# Epoch 65/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8054 - acc: 0.3772 - val_loss: 2.1850 - val_acc: 0.3435
# Epoch 66/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8047 - acc: 0.3780 - val_loss: 2.1814 - val_acc: 0.3406
# Epoch 67/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8037 - acc: 0.3808 - val_loss: 2.1783 - val_acc: 0.3440
# Epoch 68/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8029 - acc: 0.3799 - val_loss: 2.1745 - val_acc: 0.3412
# Epoch 69/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.8027 - acc: 0.3785 - val_loss: 2.1728 - val_acc: 0.3441
# Epoch 70/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.8023 - acc: 0.3789 - val_loss: 2.1689 - val_acc: 0.3401
# Epoch 71/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8016 - acc: 0.3790 - val_loss: 2.1653 - val_acc: 0.3398
# Epoch 72/100
# 10000/10000 [==============================] - 1s 50us/step - loss: 1.8007 - acc: 0.3809 - val_loss: 2.1636 - val_acc: 0.3397
# Epoch 73/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8004 - acc: 0.3775 - val_loss: 2.1618 - val_acc: 0.3477
# Epoch 74/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8003 - acc: 0.3796 - val_loss: 2.1577 - val_acc: 0.3453
# Epoch 75/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8001 - acc: 0.3810 - val_loss: 2.1533 - val_acc: 0.3434
# Epoch 76/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7988 - acc: 0.3811 - val_loss: 2.1517 - val_acc: 0.3453
# Epoch 77/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.7987 - acc: 0.3814 - val_loss: 2.1470 - val_acc: 0.3457
# Epoch 78/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7982 - acc: 0.3791 - val_loss: 2.1450 - val_acc: 0.3457
# Epoch 79/100
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.7982 - acc: 0.3816 - val_loss: 2.1404 - val_acc: 0.3481
# Epoch 80/100
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.7974 - acc: 0.3810 - val_loss: 2.1367 - val_acc: 0.3467
# Epoch 81/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7976 - acc: 0.3814 - val_loss: 2.1329 - val_acc: 0.3465
# Epoch 82/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7970 - acc: 0.3825 - val_loss: 2.1279 - val_acc: 0.3428
# Epoch 83/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7967 - acc: 0.3830 - val_loss: 2.1260 - val_acc: 0.3481
# Epoch 84/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7961 - acc: 0.3828 - val_loss: 2.1223 - val_acc: 0.3440
# Epoch 85/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7963 - acc: 0.3823 - val_loss: 2.1202 - val_acc: 0.3470
# Epoch 86/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7960 - acc: 0.3821 - val_loss: 2.1160 - val_acc: 0.3475
# Epoch 87/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7949 - acc: 0.3826 - val_loss: 2.1128 - val_acc: 0.3471
# Epoch 88/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7950 - acc: 0.3817 - val_loss: 2.1078 - val_acc: 0.3482
# Epoch 89/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7951 - acc: 0.3812 - val_loss: 2.1035 - val_acc: 0.3485
# Epoch 90/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7947 - acc: 0.3838 - val_loss: 2.1005 - val_acc: 0.3464
# Epoch 91/100
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.7942 - acc: 0.3841 - val_loss: 2.0973 - val_acc: 0.3474
# Epoch 92/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7945 - acc: 0.3835 - val_loss: 2.0919 - val_acc: 0.3500
# Epoch 93/100
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.7940 - acc: 0.3819 - val_loss: 2.0864 - val_acc: 0.3424
# Epoch 94/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7937 - acc: 0.3841 - val_loss: 2.0834 - val_acc: 0.3475
# Epoch 95/100
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.7942 - acc: 0.3834 - val_loss: 2.0806 - val_acc: 0.3476
# Epoch 96/100
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.7929 - acc: 0.3850 - val_loss: 2.0749 - val_acc: 0.3467
# Epoch 97/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7925 - acc: 0.3836 - val_loss: 2.0712 - val_acc: 0.3466
# Epoch 98/100
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.7932 - acc: 0.3837 - val_loss: 2.0671 - val_acc: 0.3488
# Epoch 99/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7931 - acc: 0.3813 - val_loss: 2.0647 - val_acc: 0.3513
# Epoch 100/100
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.7926 - acc: 0.3850 - val_loss: 2.0612 - val_acc: 0.3489
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/120
# 10000/10000 [==============================] - 1s 50us/step - loss: 2.2926 - acc: 0.1552 - val_loss: 2.3017 - val_acc: 0.1182
# Epoch 2/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 2.2656 - acc: 0.2334 - val_loss: 2.3008 - val_acc: 0.1031
# Epoch 3/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 2.2410 - acc: 0.2432 - val_loss: 2.2998 - val_acc: 0.1022
# Epoch 4/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.2175 - acc: 0.2449 - val_loss: 2.2987 - val_acc: 0.1028
# Epoch 5/120
# 10000/10000 [==============================] - 0s 49us/step - loss: 2.1962 - acc: 0.2461 - val_loss: 2.2976 - val_acc: 0.1047
# Epoch 6/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.1766 - acc: 0.2480 - val_loss: 2.2965 - val_acc: 0.1074
# Epoch 7/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.1587 - acc: 0.2528 - val_loss: 2.2954 - val_acc: 0.1092
# Epoch 8/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.1428 - acc: 0.2539 - val_loss: 2.2943 - val_acc: 0.1122
# Epoch 9/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 2.1283 - acc: 0.2580 - val_loss: 2.2931 - val_acc: 0.1148
# Epoch 10/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.1150 - acc: 0.2612 - val_loss: 2.2920 - val_acc: 0.1163
# Epoch 11/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 2.1031 - acc: 0.2637 - val_loss: 2.2909 - val_acc: 0.1179
# Epoch 12/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 2.0921 - acc: 0.2676 - val_loss: 2.2898 - val_acc: 0.1205
# Epoch 13/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 2.0817 - acc: 0.2707 - val_loss: 2.2886 - val_acc: 0.1241
# Epoch 14/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 2.0723 - acc: 0.2740 - val_loss: 2.2874 - val_acc: 0.1297
# Epoch 15/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.0636 - acc: 0.2759 - val_loss: 2.2863 - val_acc: 0.1336
# Epoch 16/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 2.0558 - acc: 0.2779 - val_loss: 2.2852 - val_acc: 0.1387
# Epoch 17/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.0477 - acc: 0.2808 - val_loss: 2.2840 - val_acc: 0.1467
# Epoch 18/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 2.0405 - acc: 0.2825 - val_loss: 2.2828 - val_acc: 0.1508
# Epoch 19/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 2.0332 - acc: 0.2860 - val_loss: 2.2816 - val_acc: 0.1569
# Epoch 20/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 2.0267 - acc: 0.2885 - val_loss: 2.2803 - val_acc: 0.1654
# Epoch 21/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 2.0205 - acc: 0.2891 - val_loss: 2.2791 - val_acc: 0.1739
# Epoch 22/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 2.0145 - acc: 0.2906 - val_loss: 2.2780 - val_acc: 0.1768
# Epoch 23/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 2.0089 - acc: 0.2933 - val_loss: 2.2768 - val_acc: 0.1853
# Epoch 24/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 2.0034 - acc: 0.2957 - val_loss: 2.2756 - val_acc: 0.1870
# Epoch 25/120
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.9982 - acc: 0.2986 - val_loss: 2.2743 - val_acc: 0.1967
# Epoch 26/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.9933 - acc: 0.3017 - val_loss: 2.2729 - val_acc: 0.2039
# Epoch 27/120
# 10000/10000 [==============================] - 1s 52us/step - loss: 1.9882 - acc: 0.3020 - val_loss: 2.2716 - val_acc: 0.2077
# Epoch 28/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.9835 - acc: 0.3033 - val_loss: 2.2702 - val_acc: 0.2137
# Epoch 29/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9792 - acc: 0.3061 - val_loss: 2.2690 - val_acc: 0.2155
# Epoch 30/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9750 - acc: 0.3070 - val_loss: 2.2676 - val_acc: 0.2209
# Epoch 31/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.9707 - acc: 0.3099 - val_loss: 2.2662 - val_acc: 0.2268
# Epoch 32/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9668 - acc: 0.3104 - val_loss: 2.2648 - val_acc: 0.2325
# Epoch 33/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.9631 - acc: 0.3132 - val_loss: 2.2634 - val_acc: 0.2403
# Epoch 34/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.9594 - acc: 0.3135 - val_loss: 2.2619 - val_acc: 0.2419
# Epoch 35/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9560 - acc: 0.3142 - val_loss: 2.2605 - val_acc: 0.2442
# Epoch 36/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.9526 - acc: 0.3169 - val_loss: 2.2591 - val_acc: 0.2481
# Epoch 37/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9496 - acc: 0.3172 - val_loss: 2.2577 - val_acc: 0.2513
# Epoch 38/120
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.9464 - acc: 0.3173 - val_loss: 2.2563 - val_acc: 0.2540
# Epoch 39/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.9434 - acc: 0.3180 - val_loss: 2.2546 - val_acc: 0.2572
# Epoch 40/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.9404 - acc: 0.3209 - val_loss: 2.2532 - val_acc: 0.2630
# Epoch 41/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.9379 - acc: 0.3196 - val_loss: 2.2516 - val_acc: 0.2668
# Epoch 42/120
# 10000/10000 [==============================] - 0s 50us/step - loss: 1.9352 - acc: 0.3231 - val_loss: 2.2500 - val_acc: 0.2686
# Epoch 43/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.9322 - acc: 0.3237 - val_loss: 2.2481 - val_acc: 0.2738
# Epoch 44/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9295 - acc: 0.3246 - val_loss: 2.2465 - val_acc: 0.2776
# Epoch 45/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9268 - acc: 0.3281 - val_loss: 2.2448 - val_acc: 0.2764
# Epoch 46/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.9241 - acc: 0.3274 - val_loss: 2.2428 - val_acc: 0.2792
# Epoch 47/120
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.9219 - acc: 0.3280 - val_loss: 2.2411 - val_acc: 0.2812
# Epoch 48/120
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.9195 - acc: 0.3285 - val_loss: 2.2390 - val_acc: 0.2838
# Epoch 49/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.9174 - acc: 0.3296 - val_loss: 2.2373 - val_acc: 0.2859
# Epoch 50/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.9145 - acc: 0.3300 - val_loss: 2.2353 - val_acc: 0.2888
# Epoch 51/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.9124 - acc: 0.3314 - val_loss: 2.2334 - val_acc: 0.2909
# Epoch 52/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.9101 - acc: 0.3356 - val_loss: 2.2314 - val_acc: 0.2928
# Epoch 53/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.9081 - acc: 0.3344 - val_loss: 2.2291 - val_acc: 0.2942
# Epoch 54/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9062 - acc: 0.3343 - val_loss: 2.2272 - val_acc: 0.2940
# Epoch 55/120
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.9041 - acc: 0.3363 - val_loss: 2.2250 - val_acc: 0.2949
# Epoch 56/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.9019 - acc: 0.3360 - val_loss: 2.2227 - val_acc: 0.2977
# Epoch 57/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.9002 - acc: 0.3373 - val_loss: 2.2205 - val_acc: 0.3009
# Epoch 58/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8978 - acc: 0.3385 - val_loss: 2.2185 - val_acc: 0.3019
# Epoch 59/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8961 - acc: 0.3408 - val_loss: 2.2159 - val_acc: 0.3035
# Epoch 60/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8942 - acc: 0.3413 - val_loss: 2.2137 - val_acc: 0.3039
# Epoch 61/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8923 - acc: 0.3413 - val_loss: 2.2112 - val_acc: 0.3065
# Epoch 62/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8905 - acc: 0.3417 - val_loss: 2.2087 - val_acc: 0.3074
# Epoch 63/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8887 - acc: 0.3432 - val_loss: 2.2062 - val_acc: 0.3101
# Epoch 64/120
# 10000/10000 [==============================] - 1s 51us/step - loss: 1.8871 - acc: 0.3446 - val_loss: 2.2035 - val_acc: 0.3124
# Epoch 65/120
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8854 - acc: 0.3455 - val_loss: 2.2009 - val_acc: 0.3119
# Epoch 66/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8834 - acc: 0.3449 - val_loss: 2.1983 - val_acc: 0.3139
# Epoch 67/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8820 - acc: 0.3465 - val_loss: 2.1955 - val_acc: 0.3162
# Epoch 68/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8806 - acc: 0.3488 - val_loss: 2.1927 - val_acc: 0.3156
# Epoch 69/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8789 - acc: 0.3475 - val_loss: 2.1898 - val_acc: 0.3179
# Epoch 70/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8775 - acc: 0.3485 - val_loss: 2.1868 - val_acc: 0.3187
# Epoch 71/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8760 - acc: 0.3482 - val_loss: 2.1841 - val_acc: 0.3196
# Epoch 72/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8749 - acc: 0.3491 - val_loss: 2.1812 - val_acc: 0.3208
# Epoch 73/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8734 - acc: 0.3481 - val_loss: 2.1778 - val_acc: 0.3217
# Epoch 74/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8716 - acc: 0.3488 - val_loss: 2.1754 - val_acc: 0.3212
# Epoch 75/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8706 - acc: 0.3512 - val_loss: 2.1720 - val_acc: 0.3220
# Epoch 76/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8689 - acc: 0.3509 - val_loss: 2.1689 - val_acc: 0.3227
# Epoch 77/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8677 - acc: 0.3523 - val_loss: 2.1660 - val_acc: 0.3228
# Epoch 78/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8667 - acc: 0.3513 - val_loss: 2.1622 - val_acc: 0.3228
# Epoch 79/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8652 - acc: 0.3534 - val_loss: 2.1590 - val_acc: 0.3239
# Epoch 80/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8638 - acc: 0.3543 - val_loss: 2.1556 - val_acc: 0.3253
# Epoch 81/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8625 - acc: 0.3539 - val_loss: 2.1519 - val_acc: 0.3241
# Epoch 82/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8614 - acc: 0.3531 - val_loss: 2.1486 - val_acc: 0.3256
# Epoch 83/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8601 - acc: 0.3546 - val_loss: 2.1452 - val_acc: 0.3247
# Epoch 84/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8590 - acc: 0.3541 - val_loss: 2.1410 - val_acc: 0.3238
# Epoch 85/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8577 - acc: 0.3526 - val_loss: 2.1376 - val_acc: 0.3265
# Epoch 86/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8568 - acc: 0.3564 - val_loss: 2.1339 - val_acc: 0.3276
# Epoch 87/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8556 - acc: 0.3550 - val_loss: 2.1304 - val_acc: 0.3287
# Epoch 88/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8548 - acc: 0.3564 - val_loss: 2.1262 - val_acc: 0.3295
# Epoch 89/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8536 - acc: 0.3555 - val_loss: 2.1219 - val_acc: 0.3292
# Epoch 90/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8531 - acc: 0.3569 - val_loss: 2.1178 - val_acc: 0.3297
# Epoch 91/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8516 - acc: 0.3570 - val_loss: 2.1141 - val_acc: 0.3289
# Epoch 92/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8507 - acc: 0.3580 - val_loss: 2.1102 - val_acc: 0.3297
# Epoch 93/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8496 - acc: 0.3581 - val_loss: 2.1064 - val_acc: 0.3298
# Epoch 94/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8488 - acc: 0.3580 - val_loss: 2.1026 - val_acc: 0.3303
# Epoch 95/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8479 - acc: 0.3590 - val_loss: 2.0988 - val_acc: 0.3303
# Epoch 96/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8468 - acc: 0.3612 - val_loss: 2.0943 - val_acc: 0.3318
# Epoch 97/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8457 - acc: 0.3607 - val_loss: 2.0902 - val_acc: 0.3313
# Epoch 98/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8450 - acc: 0.3589 - val_loss: 2.0855 - val_acc: 0.3312
# Epoch 99/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8441 - acc: 0.3602 - val_loss: 2.0819 - val_acc: 0.3325
# Epoch 100/120
# 10000/10000 [==============================] - 0s 49us/step - loss: 1.8434 - acc: 0.3604 - val_loss: 2.0770 - val_acc: 0.3329
# Epoch 101/120
# 10000/10000 [==============================] - 0s 48us/step - loss: 1.8420 - acc: 0.3624 - val_loss: 2.0728 - val_acc: 0.3337
# Epoch 102/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8412 - acc: 0.3628 - val_loss: 2.0688 - val_acc: 0.3337
# Epoch 103/120
# 10000/10000 [==============================] - 0s 46us/step - loss: 1.8406 - acc: 0.3622 - val_loss: 2.0646 - val_acc: 0.3340
# Epoch 104/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8398 - acc: 0.3635 - val_loss: 2.0604 - val_acc: 0.3343
# Epoch 105/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8390 - acc: 0.3631 - val_loss: 2.0561 - val_acc: 0.3360
# Epoch 106/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8384 - acc: 0.3634 - val_loss: 2.0517 - val_acc: 0.3355
# Epoch 107/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8381 - acc: 0.3630 - val_loss: 2.0476 - val_acc: 0.3354
# Epoch 108/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8364 - acc: 0.3645 - val_loss: 2.0434 - val_acc: 0.3347
# Epoch 109/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8359 - acc: 0.3639 - val_loss: 2.0391 - val_acc: 0.3347
# Epoch 110/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8354 - acc: 0.3646 - val_loss: 2.0346 - val_acc: 0.3358
# Epoch 111/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8344 - acc: 0.3652 - val_loss: 2.0305 - val_acc: 0.3367
# Epoch 112/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8338 - acc: 0.3662 - val_loss: 2.0267 - val_acc: 0.3363
# Epoch 113/120
# 10000/10000 [==============================] - 0s 43us/step - loss: 1.8332 - acc: 0.3655 - val_loss: 2.0226 - val_acc: 0.3375
# Epoch 114/120
# 10000/10000 [==============================] - 0s 45us/step - loss: 1.8327 - acc: 0.3660 - val_loss: 2.0185 - val_acc: 0.3358
# Epoch 115/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8319 - acc: 0.3662 - val_loss: 2.0142 - val_acc: 0.3376
# Epoch 116/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8309 - acc: 0.3663 - val_loss: 2.0103 - val_acc: 0.3378
# Epoch 117/120
# 10000/10000 [==============================] - 0s 47us/step - loss: 1.8304 - acc: 0.3664 - val_loss: 2.0059 - val_acc: 0.3379
# Epoch 118/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8299 - acc: 0.3671 - val_loss: 2.0014 - val_acc: 0.3380
# Epoch 119/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8290 - acc: 0.3670 - val_loss: 1.9983 - val_acc: 0.3385
# Epoch 120/120
# 10000/10000 [==============================] - 0s 44us/step - loss: 1.8285 - acc: 0.3680 - val_loss: 1.9945 - val_acc: 0.3387

# %%
def get_aspect(ax=None):  # used to compute rotation of text here under
    if ax is None:
        ax = plt.gca()
    fig = ax.figure

    ll, ur = ax.get_position() * fig.get_size_inches()
    width, height = ur - ll
    axes_ratio = height / width
    aspect = axes_ratio / ax.get_data_ratio()

    return aspect

# %%
mpld3.disable_notebook()
matplotlib.rcParams.update({'font.size': 18})

lrs = [3**-2,3**-3,3**-4, 3**-5]
lrs_text = ['lr = $3^{-2}$', 'lr = $3^{-3}$', 'lr = $3^{-4}$', 'lr = $3^{-5}$']

results = load_results()
plt.figure()
plt.ylim([0,1])
plt.xlim([0,100])

for i,lr in enumerate(lrs):
    ladc_dense0 = np.array(results[lr]['ladc'])[:,0]
    
    plt.plot(range(len(ladc_dense0)),ladc_dense0)
    
    x_coord = 50+5*i
    diff = 30
    angle = m.atan((ladc_dense0[x_coord+diff]-ladc_dense0[x_coord])/diff*get_aspect())*180/m.pi
    
    plt.annotate(lrs_text[i], xy=(x_coord, ladc_dense0[x_coord]), xycoords='data', color = 'C'+str(i), size = 20,
                 rotation = angle+5, rotation_mode='anchor',
                 xytext = (0,5), textcoords = 'offset points')

plt.xlabel('Epoch')
plt.ylabel('Cosine distance')

plt.savefig('figures/cifar_layer_rotations1.png',format='png', dpi=200, bbox_inches="tight")

# %%
lrs = [3**-2,3**-3,3**-4, 3**-5]

results = load_results()
test_performances = []
train_performances = []
for lr in lrs:
    test_performances.append(results[lr]['history']['history']['val_acc'][-1])
    train_performances.append(results[lr]['history']['history']['acc'][-1])
print(test_performances)
print()
print(train_performances)
# Out:
# [0.3441000009536743, 0.35139999766349794, 0.34890000128746035, 0.338700000667572]
#
# [0.38759999737739564, 0.38820000147819517, 0.38499999952316283, 0.3679999998092651]

# %%
lrs = [3**-2,3**-3,3**-4, 3**-5]

results = load_results()
model = get_model()

mpld3.disable_notebook()
nb_neurons = 5
neurons_per_line = nb_neurons
f, axes = plt.subplots(len(lrs), nb_neurons, 
                       figsize = (nb_neurons*3,len(lrs)*3))
for i,lr in enumerate(lrs):
    model.load_weights('saved_weights_cifar1/'+str(round(lr,6))[2:]+'.h5')
    
    weights = model.get_weights()[0]
    visualize_1stlayer_weights(weights,nb_neurons = nb_neurons, neuron_indices = range(5,10),
                               neurons_per_line = neurons_per_line, axes = axes[i])
    
    pad = -160
    axes[i,-1].annotate(' Train: '+str(round(results[lr]['history']['history']['acc'][-1]*100,2))+'%'+
                        '\n Test: '+str(round(results[lr]['history']['history']['val_acc'][-1]*100,2))+'%', 
                        xy=(0., 0.5), xytext=(-axes[i,-1].yaxis.labelpad - pad, 0.), 
                xycoords=axes[i,-1].yaxis.label, textcoords='offset points', 
                size=25, ha='left', va='center',rotation=0)

plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=-0.3)

plt.savefig('figures/cifar_features_visualization1.png',format='png', dpi=200, bbox_inches="tight")

f, axes = plt.subplots(1, nb_neurons, 
                       figsize = (nb_neurons*3,3))
    
model.load_weights('saved_weights_cifar1/cifar_initial_weights.h5')
weights = model.get_weights()[0]
visualize_1stlayer_weights(weights,nb_neurons = nb_neurons, neuron_indices = range(5,10),
                           neurons_per_line = neurons_per_line, axes = axes)

pad = 10
axes[0].annotate('initialization', xy=(0, 0.5), xytext=(-axes[0].yaxis.labelpad - pad, 0),
            xycoords=axes[0].yaxis.label, textcoords='offset points',
            size=25, ha='right', va='center',rotation=90)

plt.subplots_adjust(wspace=0.3)
# plt.subplots_adjust(hspace=-0.3)


plt.savefig('figures/cifar_initialization_visualization1.png',format='png', dpi=200, bbox_inches="tight")
# Out:
# c:\Users\rjtdu\OneDrive\Desktop\LayerRotation\layer-rotation-paper-experiments\MNIST - 1st layer feature visualization\feature_visualization.py:27: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   kernel = weights[index].reshape((28,28))

# %%
# ----------------------------------
# 8. Metrics: Accuracy, Precision, Recall, F1, AUC
# ----------------------------------

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
model = get_model()
model.load_weights('saved_weights_cifar1/'+str(round(lr,6))[2:]+'.h5')
y_pred = model.predict(x_test)
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)


accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='macro')
recall = recall_score(y_true, y_pred_classes, average='macro')
f1 = f1_score(y_true, y_pred_classes, average='macro')
auc = roc_auc_score(y_test, y_pred, multi_class='ovr')


print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("AUC:", auc)
# Out:
# Accuracy: 0.3387
# Precision: 0.33355208624003946
# Recall: 0.33870000000000006
# F1 Score: 0.3326865303444105
# AUC: 0.7730601555555555
