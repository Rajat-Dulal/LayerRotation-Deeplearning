# %% [markdown]
# Result computation and analysis of MNIST toy experiment. Goal is to see on a toy example how layer rotation affects the features learned by a network.
#
#
# Experiment info:
#
# 1 layer MLP (784 hidden) + batchnorm (batchnorm was used to enable larger layer rotations)
# reduced MNIST dataset (1000 samples per class) (to increase overparametrization)
# Layca as optimization algorithm
# different initial learning rates

# %%
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import sys
sys.path.insert(0, "../")

import warnings
import os
import time

import math as m
import numpy as np
np.random.seed(1)

import matplotlib
import matplotlib.pyplot as plt
import pickle

from keras.layers import Input, Dense, BatchNormalization, Activation
from keras.models import Model
from layca_optimizers import SGD
from keras.callbacks import LearningRateScheduler

from experiment_utils import plot_history, history_todict
from layer_rotation_utils import LayerRotationCurves, plot_layer_rotation_curves
from experiment_utils import lr_schedule

from feature_visualization import visualize_1stlayer_weights
from utils import load_reduced_mnist_data
# Out:
# Using TensorFlow backend.
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:469: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:470: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:471: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:472: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:473: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\rjtdu\anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\dtypes.py:476: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# utilities for storing the results in pickle files
result_file = 'results_cifar_newmodel.p'
def load_results():
    if not os.path.isfile(result_file):
        return {}
    else:
        with open(result_file,'rb') as f:
            return pickle.load(f)

def dump_results(results):
    with open(result_file,'wb') as f:
        pickle.dump(dict(results),f)

def update_results(path, new_data):
    results = load_results()
    position = results
    for p in path:
        position = position[p]
    # new_data is a dictionary with the new (key,value) pairs
    position.update(new_data)
    dump_results(results)
    
# if results should be saved in the file or not
save_results = True
if not save_results:
    results = {}

# %%
# ----------------------------------
# 1. Load CIFAR-10 dataset (Reduced)
# ----------------------------------
from keras.datasets import cifar10
from keras.utils import to_categorical
from skimage.color import rgb2gray
from skimage.transform import resize


(x_train, y_train), (x_test, y_test) = cifar10.load_data()


# Reduce dataset size to make training faster
train_samples = 10000
test_samples = 10000
x_train, y_train = x_train[:train_samples], y_train[:train_samples]
x_test, y_test = x_test[:test_samples], y_test[:test_samples]

# Convert to grayscale
x_train = np.expand_dims(rgb2gray(x_train), axis=-1)  # shape: (N, 32, 32, 1)
x_test = np.expand_dims(rgb2gray(x_test), axis=-1)    # shape: (N, 32, 32, 1)

# Resize function for all images
def resize_images(images, new_shape=(28, 28)):
    return np.array([resize(image, new_shape, anti_aliasing=True) for image in images])

# Resize your grayscale images
x_train_resized = resize_images(x_train.squeeze())  # shape: (N, 28, 28)
x_test_resized = resize_images(x_test.squeeze())    # shape: (N, 28, 28)

# Flatten each image
x_train = x_train_resized.reshape((x_train_resized.shape[0], -1))  # shape: (N, 784)
x_test = x_test_resized.reshape((x_test_resized.shape[0], -1))     # shape: (N, 784)


# Flatten each image
x_train = x_train.reshape((x_train.shape[0], -1))  # shape: (N, 32 * 32 * 3)
x_test = x_test.reshape((x_test.shape[0], -1))     # shape: (N, 32 * 32 * 3)


# Normalize data
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.


# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (10000, 784)
# (10000, 10)

# %%
def get_model():
    inp = Input((784,))
    
    # First Dense Layer
    x = Dense(784, activation='linear', name='dense0')(inp)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # New Hidden Layer
    x = Dense(256, activation='linear', name='dense1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Output Layer
    x = Dense(10, activation='softmax', name='densef')(x)
    
    return Model(inp, x)

# %%
os.makedirs('saved_weights_cifar_newmodel', exist_ok=True)

# %%
# !pip install h5py==2.10.0

# %%
import h5py
print(h5py.__version__)  # should print 2.10.0
# Out:
# 2.10.0

# %%
# configuration of the different learning rate schedules 
# (a division of the learning rate by 5 is used to escape plateaus in the loss curve)
training_configs = {3**-2: (100, LearningRateScheduler(lr_schedule(3**-2,1./5.,[90]))),
                    3**-2.5: (100, LearningRateScheduler(lr_schedule(3**-2.5,1./5.,[95]))),
                    3**-3: (100, LearningRateScheduler(lr_schedule(3**-3,1./5.,[95]))),
                    3**-4: (100, LearningRateScheduler(lr_schedule(3**-4,1.,[np.inf]))),
                    3**-5: (120, LearningRateScheduler(lr_schedule(3**-5,1.,[np.inf]))),
                    3**-6: (300, LearningRateScheduler(lr_schedule(3**-6,1.,[np.inf]))),
                    3**-7: (1000, LearningRateScheduler(lr_schedule(3**-7,1.,[np.inf])))}

lrs = [3**-2,3**-3,3**-4, 3**-5]
for lr in lrs:
    model = get_model()

    weights_location = 'saved_weights_cifar_newmodel/cifar_initial_weights.h5'
    if not os.path.isfile(weights_location):
        model.save_weights(weights_location)
    else:
        model.load_weights(weights_location)

    epochs = training_configs[lr][0]
    lr_sched = training_configs[lr][1]

    ladc = LayerRotationCurves(batch_frequency = np.inf)

    model.compile(loss='categorical_crossentropy',
                  optimizer=SGD(lr,layca = True),
                  metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                        batch_size=2048,
                        epochs=epochs,
                        verbose=1,
                        validation_data = (x_test,y_test),
                        callbacks = [ladc, lr_sched])


    if save_results:
        update_results([],{lr:{'history':history_todict(history),'ladc':ladc.memory}})
    else:
        results.update({lr:{'history':history_todict(history),'ladc':ladc.memory}})

    if save_results:
        model.save_weights('saved_weights_cifar_newmodel/'+str(round(lr,6))[2:]+'.h5')
# Out:
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/100
# 10000/10000 [==============================] - 1s 70us/step - loss: 2.8783 - acc: 0.1788 - val_loss: 2.3007 - val_acc: 0.1012
# Epoch 2/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 2.5307 - acc: 0.2227 - val_loss: 2.3024 - val_acc: 0.1017
# Epoch 3/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 2.3598 - acc: 0.2440 - val_loss: 2.3012 - val_acc: 0.0997
# Epoch 4/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 2.1771 - acc: 0.2823 - val_loss: 2.2966 - val_acc: 0.1681
# Epoch 5/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 2.1345 - acc: 0.2916 - val_loss: 2.2900 - val_acc: 0.1811
# Epoch 6/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 2.0633 - acc: 0.3133 - val_loss: 2.2898 - val_acc: 0.1662
# Epoch 7/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 2.0293 - acc: 0.3160 - val_loss: 2.2868 - val_acc: 0.1599
# Epoch 8/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.9626 - acc: 0.3270 - val_loss: 2.2858 - val_acc: 0.1303
# Epoch 9/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 1.9457 - acc: 0.3466 - val_loss: 2.2952 - val_acc: 0.1300
# Epoch 10/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.9256 - acc: 0.3375 - val_loss: 2.2842 - val_acc: 0.1404
# Epoch 11/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.9073 - acc: 0.3481 - val_loss: 2.2814 - val_acc: 0.1565
# Epoch 12/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.8546 - acc: 0.3583 - val_loss: 2.2985 - val_acc: 0.1111
# Epoch 13/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.8200 - acc: 0.3745 - val_loss: 2.3076 - val_acc: 0.1310
# Epoch 14/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.8041 - acc: 0.3894 - val_loss: 2.3032 - val_acc: 0.1279
# Epoch 15/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.8003 - acc: 0.3792 - val_loss: 2.3121 - val_acc: 0.1152
# Epoch 16/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.7861 - acc: 0.3877 - val_loss: 2.3466 - val_acc: 0.1229
# Epoch 17/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.7546 - acc: 0.4014 - val_loss: 2.3755 - val_acc: 0.1001
# Epoch 18/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.7253 - acc: 0.4003 - val_loss: 2.3299 - val_acc: 0.1174
# Epoch 19/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.7075 - acc: 0.4243 - val_loss: 2.3608 - val_acc: 0.1112
# Epoch 20/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.6823 - acc: 0.4147 - val_loss: 2.3742 - val_acc: 0.1217
# Epoch 21/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.6978 - acc: 0.4181 - val_loss: 2.4202 - val_acc: 0.1266
# Epoch 22/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.6602 - acc: 0.4276 - val_loss: 2.4311 - val_acc: 0.1003
# Epoch 23/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.6844 - acc: 0.4137 - val_loss: 2.3902 - val_acc: 0.1133
# Epoch 24/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.6235 - acc: 0.4456 - val_loss: 2.4665 - val_acc: 0.1012
# Epoch 25/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.6319 - acc: 0.4369 - val_loss: 2.4479 - val_acc: 0.1257
# Epoch 26/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.6444 - acc: 0.4304 - val_loss: 2.4782 - val_acc: 0.1000
# Epoch 27/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.6008 - acc: 0.4413 - val_loss: 2.4956 - val_acc: 0.1376
# Epoch 28/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.6230 - acc: 0.4504 - val_loss: 2.4777 - val_acc: 0.1118
# Epoch 29/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.5951 - acc: 0.4548 - val_loss: 2.4303 - val_acc: 0.1002
# Epoch 30/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.6019 - acc: 0.4534 - val_loss: 2.4297 - val_acc: 0.1080
# Epoch 31/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.5797 - acc: 0.4575 - val_loss: 2.5348 - val_acc: 0.1002
# Epoch 32/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.5671 - acc: 0.4649 - val_loss: 2.6422 - val_acc: 0.1005
# Epoch 33/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.6219 - acc: 0.4532 - val_loss: 2.6217 - val_acc: 0.1469
# Epoch 34/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.5557 - acc: 0.4640 - val_loss: 2.7429 - val_acc: 0.1220
# Epoch 35/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.5447 - acc: 0.4696 - val_loss: 2.6667 - val_acc: 0.1039
# Epoch 36/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.5192 - acc: 0.4769 - val_loss: 2.5842 - val_acc: 0.1026
# Epoch 37/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.5813 - acc: 0.4709 - val_loss: 2.6385 - val_acc: 0.1004
# Epoch 38/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 1.5405 - acc: 0.4749 - val_loss: 2.8111 - val_acc: 0.1046
# Epoch 39/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.5598 - acc: 0.4545 - val_loss: 2.7451 - val_acc: 0.1201
# Epoch 40/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.5104 - acc: 0.4842 - val_loss: 2.7775 - val_acc: 0.1035
# Epoch 41/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.4929 - acc: 0.4974 - val_loss: 2.8110 - val_acc: 0.1019
# Epoch 42/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.5069 - acc: 0.4907 - val_loss: 2.8403 - val_acc: 0.1000
# Epoch 43/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.5003 - acc: 0.4845 - val_loss: 2.7459 - val_acc: 0.1000
# Epoch 44/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.4632 - acc: 0.5039 - val_loss: 2.8301 - val_acc: 0.1063
# Epoch 45/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.5006 - acc: 0.4837 - val_loss: 2.9944 - val_acc: 0.1135
# Epoch 46/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4629 - acc: 0.4969 - val_loss: 2.8271 - val_acc: 0.1209
# Epoch 47/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 1.4739 - acc: 0.4892 - val_loss: 2.8193 - val_acc: 0.1109
# Epoch 48/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4905 - acc: 0.4889 - val_loss: 3.0583 - val_acc: 0.1000
# Epoch 49/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4773 - acc: 0.4976 - val_loss: 2.7810 - val_acc: 0.1105
# Epoch 50/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.5534 - acc: 0.4864 - val_loss: 3.1193 - val_acc: 0.1059
# Epoch 51/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.4742 - acc: 0.5025 - val_loss: 2.8133 - val_acc: 0.1025
# Epoch 52/100
# 10000/10000 [==============================] - 1s 65us/step - loss: 1.4560 - acc: 0.5094 - val_loss: 2.7523 - val_acc: 0.1004
# Epoch 53/100
# 10000/10000 [==============================] - 1s 65us/step - loss: 1.4742 - acc: 0.5005 - val_loss: 3.0151 - val_acc: 0.1003
# Epoch 54/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.4940 - acc: 0.5035 - val_loss: 3.0240 - val_acc: 0.1043
# Epoch 55/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4830 - acc: 0.5062 - val_loss: 2.8800 - val_acc: 0.1092
# Epoch 56/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 1.4529 - acc: 0.4946 - val_loss: 3.3372 - val_acc: 0.1024
# Epoch 57/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.4548 - acc: 0.5010 - val_loss: 2.9433 - val_acc: 0.1001
# Epoch 58/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 1.4518 - acc: 0.4977 - val_loss: 3.1472 - val_acc: 0.1000
# Epoch 59/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.4356 - acc: 0.5103 - val_loss: 3.0138 - val_acc: 0.1099
# Epoch 60/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.4839 - acc: 0.4979 - val_loss: 2.9288 - val_acc: 0.0997
# Epoch 61/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.4037 - acc: 0.5242 - val_loss: 2.7317 - val_acc: 0.1351
# Epoch 62/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4720 - acc: 0.5050 - val_loss: 2.7286 - val_acc: 0.1060
# Epoch 63/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4211 - acc: 0.5222 - val_loss: 2.9344 - val_acc: 0.1223
# Epoch 64/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.4171 - acc: 0.5209 - val_loss: 2.6839 - val_acc: 0.1143
# Epoch 65/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.5387 - acc: 0.5014 - val_loss: 2.8941 - val_acc: 0.1178
# Epoch 66/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.4356 - acc: 0.5118 - val_loss: 2.7786 - val_acc: 0.1566
# Epoch 67/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4269 - acc: 0.5209 - val_loss: 3.1296 - val_acc: 0.1080
# Epoch 68/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.4508 - acc: 0.5202 - val_loss: 2.7369 - val_acc: 0.1125
# Epoch 69/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.4409 - acc: 0.5154 - val_loss: 3.2886 - val_acc: 0.1034
# Epoch 70/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4576 - acc: 0.5066 - val_loss: 2.8170 - val_acc: 0.1590
# Epoch 71/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.4320 - acc: 0.5180 - val_loss: 3.1074 - val_acc: 0.1437
# Epoch 72/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4216 - acc: 0.5223 - val_loss: 2.9982 - val_acc: 0.1097
# Epoch 73/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.3998 - acc: 0.5249 - val_loss: 2.6744 - val_acc: 0.1464
# Epoch 74/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.4063 - acc: 0.5344 - val_loss: 3.1421 - val_acc: 0.1107
# Epoch 75/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4388 - acc: 0.5239 - val_loss: 3.1232 - val_acc: 0.1033
# Epoch 76/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4165 - acc: 0.5144 - val_loss: 2.9429 - val_acc: 0.1359
# Epoch 77/100
# 10000/10000 [==============================] - 1s 55us/step - loss: 1.4205 - acc: 0.5163 - val_loss: 3.4587 - val_acc: 0.1045
# Epoch 78/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 1.4325 - acc: 0.5206 - val_loss: 2.3352 - val_acc: 0.1639
# Epoch 79/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4002 - acc: 0.5313 - val_loss: 2.9835 - val_acc: 0.1288
# Epoch 80/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.4079 - acc: 0.5174 - val_loss: 3.3832 - val_acc: 0.1027
# Epoch 81/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4211 - acc: 0.5223 - val_loss: 3.3333 - val_acc: 0.1002
# Epoch 82/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4202 - acc: 0.5266 - val_loss: 2.8355 - val_acc: 0.1209
# Epoch 83/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4421 - acc: 0.5141 - val_loss: 3.0917 - val_acc: 0.1349
# Epoch 84/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.4024 - acc: 0.5262 - val_loss: 3.4948 - val_acc: 0.1246
# Epoch 85/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.3913 - acc: 0.5331 - val_loss: 3.9800 - val_acc: 0.1001
# Epoch 86/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4109 - acc: 0.5183 - val_loss: 2.6625 - val_acc: 0.1334
# Epoch 87/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.4034 - acc: 0.5352 - val_loss: 2.4830 - val_acc: 0.1637
# Epoch 88/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.3903 - acc: 0.5225 - val_loss: 2.9286 - val_acc: 0.1314
# Epoch 89/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.4172 - acc: 0.5117 - val_loss: 2.5599 - val_acc: 0.1381
# Epoch 90/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.3913 - acc: 0.5207 - val_loss: 2.7453 - val_acc: 0.1730
# Epoch 91/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0079 - acc: 0.6834 - val_loss: 2.9318 - val_acc: 0.1499
# Epoch 92/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.8041 - acc: 0.7597 - val_loss: 2.9385 - val_acc: 0.1308
# Epoch 93/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.7638 - acc: 0.7757 - val_loss: 3.2147 - val_acc: 0.1320
# Epoch 94/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7282 - acc: 0.7856 - val_loss: 3.0926 - val_acc: 0.1440
# Epoch 95/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7039 - acc: 0.7918 - val_loss: 3.0230 - val_acc: 0.1237
# Epoch 96/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.6794 - acc: 0.8039 - val_loss: 2.7786 - val_acc: 0.1480
# Epoch 97/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.6638 - acc: 0.8115 - val_loss: 3.1874 - val_acc: 0.1489
# Epoch 98/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.6425 - acc: 0.8189 - val_loss: 2.8783 - val_acc: 0.1132
# Epoch 99/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.6271 - acc: 0.8229 - val_loss: 2.9705 - val_acc: 0.1326
# Epoch 100/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.6122 - acc: 0.8323 - val_loss: 2.9053 - val_acc: 0.1281
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/100
# 10000/10000 [==============================] - 1s 70us/step - loss: 2.3725 - acc: 0.2078 - val_loss: 2.3017 - val_acc: 0.1810
# Epoch 2/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 2.0885 - acc: 0.2980 - val_loss: 2.3014 - val_acc: 0.1021
# Epoch 3/100
# 10000/10000 [==============================] - 1s 65us/step - loss: 1.9632 - acc: 0.3254 - val_loss: 2.3008 - val_acc: 0.1937
# Epoch 4/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 1.8742 - acc: 0.3367 - val_loss: 2.3009 - val_acc: 0.1507
# Epoch 5/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 1.8003 - acc: 0.3720 - val_loss: 2.3005 - val_acc: 0.1109
# Epoch 6/100
# 10000/10000 [==============================] - 1s 67us/step - loss: 1.7505 - acc: 0.3814 - val_loss: 2.2994 - val_acc: 0.1218
# Epoch 7/100
# 10000/10000 [==============================] - 1s 66us/step - loss: 1.7037 - acc: 0.4067 - val_loss: 2.2996 - val_acc: 0.1147
# Epoch 8/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.6444 - acc: 0.4251 - val_loss: 2.2991 - val_acc: 0.1292
# Epoch 9/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.6193 - acc: 0.4325 - val_loss: 2.2983 - val_acc: 0.1467
# Epoch 10/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.5753 - acc: 0.4500 - val_loss: 2.2993 - val_acc: 0.1011
# Epoch 11/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.5509 - acc: 0.4626 - val_loss: 2.2984 - val_acc: 0.1020
# Epoch 12/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.5043 - acc: 0.4754 - val_loss: 2.2994 - val_acc: 0.1001
# Epoch 13/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4726 - acc: 0.4932 - val_loss: 2.2994 - val_acc: 0.1021
# Epoch 14/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4595 - acc: 0.5030 - val_loss: 2.2985 - val_acc: 0.1066
# Epoch 15/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4264 - acc: 0.5085 - val_loss: 2.3001 - val_acc: 0.1046
# Epoch 16/100
# 10000/10000 [==============================] - 1s 67us/step - loss: 1.4380 - acc: 0.5058 - val_loss: 2.3011 - val_acc: 0.1001
# Epoch 17/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.3787 - acc: 0.5327 - val_loss: 2.2980 - val_acc: 0.1245
# Epoch 18/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.3623 - acc: 0.5374 - val_loss: 2.2976 - val_acc: 0.1069
# Epoch 19/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 1.3720 - acc: 0.5347 - val_loss: 2.3037 - val_acc: 0.1009
# Epoch 20/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.3406 - acc: 0.5394 - val_loss: 2.3027 - val_acc: 0.1000
# Epoch 21/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.3240 - acc: 0.5533 - val_loss: 2.3017 - val_acc: 0.1003
# Epoch 22/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.2915 - acc: 0.5734 - val_loss: 2.2980 - val_acc: 0.1381
# Epoch 23/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.2841 - acc: 0.5725 - val_loss: 2.2997 - val_acc: 0.1148
# Epoch 24/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.2728 - acc: 0.5750 - val_loss: 2.3025 - val_acc: 0.1000
# Epoch 25/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.2654 - acc: 0.5726 - val_loss: 2.3032 - val_acc: 0.1674
# Epoch 26/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.2408 - acc: 0.5906 - val_loss: 2.3056 - val_acc: 0.1001
# Epoch 27/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.2227 - acc: 0.5908 - val_loss: 2.3031 - val_acc: 0.1063
# Epoch 28/100
# 10000/10000 [==============================] - 1s 65us/step - loss: 1.1979 - acc: 0.6141 - val_loss: 2.3097 - val_acc: 0.1000
# Epoch 29/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 1.2118 - acc: 0.5985 - val_loss: 2.3109 - val_acc: 0.1001
# Epoch 30/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 1.1932 - acc: 0.6058 - val_loss: 2.3123 - val_acc: 0.1001
# Epoch 31/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 1.1525 - acc: 0.6232 - val_loss: 2.3041 - val_acc: 0.1225
# Epoch 32/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 1.1791 - acc: 0.6180 - val_loss: 2.3153 - val_acc: 0.1001
# Epoch 33/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 1.1348 - acc: 0.6369 - val_loss: 2.3215 - val_acc: 0.1032
# Epoch 34/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.1303 - acc: 0.6301 - val_loss: 2.3183 - val_acc: 0.1193
# Epoch 35/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.1060 - acc: 0.6362 - val_loss: 2.3322 - val_acc: 0.1001
# Epoch 36/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 1.1393 - acc: 0.6324 - val_loss: 2.3181 - val_acc: 0.1007
# Epoch 37/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 1.0840 - acc: 0.6431 - val_loss: 2.3206 - val_acc: 0.1001
# Epoch 38/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 1.0821 - acc: 0.6518 - val_loss: 2.3326 - val_acc: 0.1000
# Epoch 39/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.0649 - acc: 0.6579 - val_loss: 2.3229 - val_acc: 0.1053
# Epoch 40/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.0600 - acc: 0.6642 - val_loss: 2.3389 - val_acc: 0.1002
# Epoch 41/100
# 10000/10000 [==============================] - 1s 65us/step - loss: 1.0629 - acc: 0.6687 - val_loss: 2.3252 - val_acc: 0.1486
# Epoch 42/100
# 10000/10000 [==============================] - 1s 67us/step - loss: 1.0539 - acc: 0.6571 - val_loss: 2.3300 - val_acc: 0.1383
# Epoch 43/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 1.0282 - acc: 0.6760 - val_loss: 2.3340 - val_acc: 0.1097
# Epoch 44/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.0276 - acc: 0.6684 - val_loss: 2.3459 - val_acc: 0.0952
# Epoch 45/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.0209 - acc: 0.6838 - val_loss: 2.3583 - val_acc: 0.1004
# Epoch 46/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9976 - acc: 0.6938 - val_loss: 2.3385 - val_acc: 0.1051
# Epoch 47/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.9949 - acc: 0.6881 - val_loss: 2.3400 - val_acc: 0.1049
# Epoch 48/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.0062 - acc: 0.6790 - val_loss: 2.3357 - val_acc: 0.1154
# Epoch 49/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.9735 - acc: 0.6922 - val_loss: 2.3202 - val_acc: 0.1504
# Epoch 50/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.9793 - acc: 0.6989 - val_loss: 2.3561 - val_acc: 0.1120
# Epoch 51/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.9681 - acc: 0.7042 - val_loss: 2.3473 - val_acc: 0.1009
# Epoch 52/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.9490 - acc: 0.7061 - val_loss: 2.3554 - val_acc: 0.1006
# Epoch 53/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.9414 - acc: 0.7127 - val_loss: 2.3516 - val_acc: 0.1045
# Epoch 54/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9294 - acc: 0.7049 - val_loss: 2.3710 - val_acc: 0.1048
# Epoch 55/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.9435 - acc: 0.7081 - val_loss: 2.3701 - val_acc: 0.1071
# Epoch 56/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.9391 - acc: 0.7049 - val_loss: 2.3509 - val_acc: 0.1740
# Epoch 57/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9251 - acc: 0.7176 - val_loss: 2.3966 - val_acc: 0.1189
# Epoch 58/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9098 - acc: 0.7252 - val_loss: 2.3668 - val_acc: 0.1306
# Epoch 59/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.9003 - acc: 0.7288 - val_loss: 2.4037 - val_acc: 0.1036
# Epoch 60/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.9196 - acc: 0.7170 - val_loss: 2.3509 - val_acc: 0.1052
# Epoch 61/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8903 - acc: 0.7330 - val_loss: 2.4458 - val_acc: 0.1240
# Epoch 62/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8881 - acc: 0.7324 - val_loss: 2.3677 - val_acc: 0.1214
# Epoch 63/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8890 - acc: 0.7247 - val_loss: 2.3447 - val_acc: 0.1747
# Epoch 64/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.8744 - acc: 0.7392 - val_loss: 2.3099 - val_acc: 0.1680
# Epoch 65/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.8884 - acc: 0.7299 - val_loss: 2.4321 - val_acc: 0.1413
# Epoch 66/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8648 - acc: 0.7400 - val_loss: 2.4458 - val_acc: 0.1352
# Epoch 67/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8604 - acc: 0.7449 - val_loss: 2.4132 - val_acc: 0.1439
# Epoch 68/100
# 10000/10000 [==============================] - 1s 65us/step - loss: 0.8768 - acc: 0.7402 - val_loss: 2.4635 - val_acc: 0.1229
# Epoch 69/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8555 - acc: 0.7497 - val_loss: 2.4467 - val_acc: 0.1190
# Epoch 70/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.8349 - acc: 0.7490 - val_loss: 2.4174 - val_acc: 0.1411
# Epoch 71/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8312 - acc: 0.7542 - val_loss: 2.4305 - val_acc: 0.1581
# Epoch 72/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.8310 - acc: 0.7524 - val_loss: 2.5323 - val_acc: 0.1283
# Epoch 73/100
# 10000/10000 [==============================] - 1s 67us/step - loss: 0.8194 - acc: 0.7594 - val_loss: 2.6085 - val_acc: 0.1006
# Epoch 74/100
# 10000/10000 [==============================] - 1s 67us/step - loss: 0.8139 - acc: 0.7575 - val_loss: 2.3714 - val_acc: 0.1550
# Epoch 75/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8232 - acc: 0.7583 - val_loss: 2.4123 - val_acc: 0.1288
# Epoch 76/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.8037 - acc: 0.7609 - val_loss: 2.4899 - val_acc: 0.1011
# Epoch 77/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8119 - acc: 0.7635 - val_loss: 2.5310 - val_acc: 0.1061
# Epoch 78/100
# 10000/10000 [==============================] - 1s 65us/step - loss: 0.7931 - acc: 0.7698 - val_loss: 2.4442 - val_acc: 0.1835
# Epoch 79/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.7999 - acc: 0.7628 - val_loss: 2.3823 - val_acc: 0.1095
# Epoch 80/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 0.8040 - acc: 0.7651 - val_loss: 2.5046 - val_acc: 0.1136
# Epoch 81/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.7886 - acc: 0.7656 - val_loss: 2.5278 - val_acc: 0.1243
# Epoch 82/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.7809 - acc: 0.7759 - val_loss: 2.6647 - val_acc: 0.1011
# Epoch 83/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8050 - acc: 0.7583 - val_loss: 2.5607 - val_acc: 0.1385
# Epoch 84/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.7628 - acc: 0.7798 - val_loss: 2.3256 - val_acc: 0.1741
# Epoch 85/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7614 - acc: 0.7796 - val_loss: 2.6375 - val_acc: 0.1242
# Epoch 86/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7806 - acc: 0.7807 - val_loss: 2.5377 - val_acc: 0.1455
# Epoch 87/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7519 - acc: 0.7852 - val_loss: 2.3658 - val_acc: 0.1688
# Epoch 88/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7471 - acc: 0.7878 - val_loss: 2.2295 - val_acc: 0.1471
# Epoch 89/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7462 - acc: 0.7883 - val_loss: 2.4037 - val_acc: 0.1497
# Epoch 90/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7895 - acc: 0.7681 - val_loss: 2.7162 - val_acc: 0.1106
# Epoch 91/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7306 - acc: 0.8002 - val_loss: 2.6215 - val_acc: 0.1476
# Epoch 92/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.7641 - acc: 0.7869 - val_loss: 2.6567 - val_acc: 0.1247
# Epoch 93/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7266 - acc: 0.7934 - val_loss: 2.9989 - val_acc: 0.1138
# Epoch 94/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.7442 - acc: 0.7863 - val_loss: 2.4330 - val_acc: 0.1759
# Epoch 95/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7408 - acc: 0.7910 - val_loss: 2.6921 - val_acc: 0.1276
# Epoch 96/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.5801 - acc: 0.8693 - val_loss: 2.4978 - val_acc: 0.1566
# Epoch 97/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.4547 - acc: 0.9242 - val_loss: 2.4354 - val_acc: 0.1500
# Epoch 98/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.4420 - acc: 0.9272 - val_loss: 2.4768 - val_acc: 0.1737
# Epoch 99/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.4279 - acc: 0.9341 - val_loss: 2.4787 - val_acc: 0.1579
# Epoch 100/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.4222 - acc: 0.9329 - val_loss: 2.4274 - val_acc: 0.1613
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/100
# 10000/10000 [==============================] - 1s 67us/step - loss: 2.1925 - acc: 0.2109 - val_loss: 2.3019 - val_acc: 0.1225
# Epoch 2/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.9554 - acc: 0.3183 - val_loss: 2.3017 - val_acc: 0.1338
# Epoch 3/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.8523 - acc: 0.3517 - val_loss: 2.3015 - val_acc: 0.1400
# Epoch 4/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.7610 - acc: 0.3840 - val_loss: 2.3013 - val_acc: 0.1207
# Epoch 5/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.7091 - acc: 0.4090 - val_loss: 2.3010 - val_acc: 0.1635
# Epoch 6/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.6589 - acc: 0.4206 - val_loss: 2.3010 - val_acc: 0.1411
# Epoch 7/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.6203 - acc: 0.4445 - val_loss: 2.3006 - val_acc: 0.1186
# Epoch 8/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.5817 - acc: 0.4598 - val_loss: 2.3006 - val_acc: 0.1159
# Epoch 9/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.5541 - acc: 0.4664 - val_loss: 2.3006 - val_acc: 0.1018
# Epoch 10/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.5168 - acc: 0.4781 - val_loss: 2.3003 - val_acc: 0.1211
# Epoch 11/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.4874 - acc: 0.5015 - val_loss: 2.3005 - val_acc: 0.1071
# Epoch 12/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4666 - acc: 0.5056 - val_loss: 2.2997 - val_acc: 0.1047
# Epoch 13/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.4435 - acc: 0.5150 - val_loss: 2.3004 - val_acc: 0.1007
# Epoch 14/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.4213 - acc: 0.5280 - val_loss: 2.2997 - val_acc: 0.1096
# Epoch 15/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.3931 - acc: 0.5314 - val_loss: 2.3003 - val_acc: 0.1023
# Epoch 16/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.3758 - acc: 0.5454 - val_loss: 2.2999 - val_acc: 0.1051
# Epoch 17/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.3617 - acc: 0.5513 - val_loss: 2.3004 - val_acc: 0.1038
# Epoch 18/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.3381 - acc: 0.5586 - val_loss: 2.3002 - val_acc: 0.1096
# Epoch 19/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.3256 - acc: 0.5652 - val_loss: 2.2996 - val_acc: 0.1044
# Epoch 20/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.3086 - acc: 0.5738 - val_loss: 2.3009 - val_acc: 0.1007
# Epoch 21/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.2894 - acc: 0.5824 - val_loss: 2.3004 - val_acc: 0.1149
# Epoch 22/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.2772 - acc: 0.5825 - val_loss: 2.2996 - val_acc: 0.1051
# Epoch 23/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.2742 - acc: 0.5874 - val_loss: 2.3005 - val_acc: 0.1063
# Epoch 24/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.2420 - acc: 0.6080 - val_loss: 2.3018 - val_acc: 0.1006
# Epoch 25/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.2326 - acc: 0.6069 - val_loss: 2.3010 - val_acc: 0.1132
# Epoch 26/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.2176 - acc: 0.6051 - val_loss: 2.3016 - val_acc: 0.1013
# Epoch 27/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.2069 - acc: 0.6227 - val_loss: 2.3038 - val_acc: 0.1002
# Epoch 28/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.1935 - acc: 0.6237 - val_loss: 2.3018 - val_acc: 0.1176
# Epoch 29/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.1772 - acc: 0.6379 - val_loss: 2.3011 - val_acc: 0.1084
# Epoch 30/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.1701 - acc: 0.6262 - val_loss: 2.3045 - val_acc: 0.1013
# Epoch 31/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.1621 - acc: 0.6414 - val_loss: 2.3040 - val_acc: 0.1095
# Epoch 32/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.1471 - acc: 0.6438 - val_loss: 2.3057 - val_acc: 0.1002
# Epoch 33/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.1293 - acc: 0.6461 - val_loss: 2.3050 - val_acc: 0.1016
# Epoch 34/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.1235 - acc: 0.6538 - val_loss: 2.3055 - val_acc: 0.1028
# Epoch 35/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.1151 - acc: 0.6562 - val_loss: 2.3040 - val_acc: 0.1019
# Epoch 36/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.1001 - acc: 0.6674 - val_loss: 2.3086 - val_acc: 0.1012
# Epoch 37/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.0837 - acc: 0.6762 - val_loss: 2.3077 - val_acc: 0.1441
# Epoch 38/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0773 - acc: 0.6748 - val_loss: 2.3048 - val_acc: 0.1006
# Epoch 39/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0643 - acc: 0.6808 - val_loss: 2.3113 - val_acc: 0.1006
# Epoch 40/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.0596 - acc: 0.6836 - val_loss: 2.3085 - val_acc: 0.1029
# Epoch 41/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.0571 - acc: 0.6813 - val_loss: 2.3112 - val_acc: 0.1201
# Epoch 42/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.0517 - acc: 0.6827 - val_loss: 2.3122 - val_acc: 0.1001
# Epoch 43/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0306 - acc: 0.6916 - val_loss: 2.3134 - val_acc: 0.1115
# Epoch 44/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.0290 - acc: 0.6985 - val_loss: 2.3115 - val_acc: 0.1270
# Epoch 45/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.0136 - acc: 0.7029 - val_loss: 2.3086 - val_acc: 0.1011
# Epoch 46/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0007 - acc: 0.7094 - val_loss: 2.3216 - val_acc: 0.1006
# Epoch 47/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9969 - acc: 0.7016 - val_loss: 2.3148 - val_acc: 0.1321
# Epoch 48/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0039 - acc: 0.7043 - val_loss: 2.3059 - val_acc: 0.1153
# Epoch 49/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.9773 - acc: 0.7099 - val_loss: 2.3211 - val_acc: 0.1068
# Epoch 50/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.9797 - acc: 0.7147 - val_loss: 2.3194 - val_acc: 0.1030
# Epoch 51/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 0.9658 - acc: 0.7228 - val_loss: 2.3228 - val_acc: 0.1006
# Epoch 52/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9659 - acc: 0.7228 - val_loss: 2.3221 - val_acc: 0.1034
# Epoch 53/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9666 - acc: 0.7200 - val_loss: 2.3328 - val_acc: 0.1014
# Epoch 54/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.9474 - acc: 0.7243 - val_loss: 2.3131 - val_acc: 0.1074
# Epoch 55/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9367 - acc: 0.7314 - val_loss: 2.3288 - val_acc: 0.1378
# Epoch 56/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.9379 - acc: 0.7289 - val_loss: 2.3275 - val_acc: 0.1034
# Epoch 57/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.9333 - acc: 0.7259 - val_loss: 2.3300 - val_acc: 0.1039
# Epoch 58/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 0.9236 - acc: 0.7350 - val_loss: 2.3276 - val_acc: 0.1117
# Epoch 59/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9175 - acc: 0.7404 - val_loss: 2.3316 - val_acc: 0.1009
# Epoch 60/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.9073 - acc: 0.7405 - val_loss: 2.3205 - val_acc: 0.1344
# Epoch 61/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9090 - acc: 0.7420 - val_loss: 2.3404 - val_acc: 0.1257
# Epoch 62/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.8995 - acc: 0.7502 - val_loss: 2.3445 - val_acc: 0.1043
# Epoch 63/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8963 - acc: 0.7471 - val_loss: 2.3363 - val_acc: 0.1457
# Epoch 64/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.8903 - acc: 0.7470 - val_loss: 2.3561 - val_acc: 0.1204
# Epoch 65/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.8807 - acc: 0.7637 - val_loss: 2.3447 - val_acc: 0.1061
# Epoch 66/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8718 - acc: 0.7558 - val_loss: 2.3152 - val_acc: 0.1567
# Epoch 67/100
# 10000/10000 [==============================] - 1s 65us/step - loss: 0.8695 - acc: 0.7592 - val_loss: 2.3576 - val_acc: 0.1240
# Epoch 68/100
# 10000/10000 [==============================] - 1s 64us/step - loss: 0.8647 - acc: 0.7575 - val_loss: 2.3192 - val_acc: 0.1009
# Epoch 69/100
# 10000/10000 [==============================] - 1s 71us/step - loss: 0.8593 - acc: 0.7547 - val_loss: 2.3665 - val_acc: 0.1163
# Epoch 70/100
# 10000/10000 [==============================] - 1s 73us/step - loss: 0.8431 - acc: 0.7709 - val_loss: 2.3210 - val_acc: 0.1268
# Epoch 71/100
# 10000/10000 [==============================] - 1s 76us/step - loss: 0.8524 - acc: 0.7581 - val_loss: 2.3467 - val_acc: 0.1522
# Epoch 72/100
# 10000/10000 [==============================] - 1s 76us/step - loss: 0.8366 - acc: 0.7752 - val_loss: 2.2987 - val_acc: 0.1078
# Epoch 73/100
# 10000/10000 [==============================] - 1s 66us/step - loss: 0.8394 - acc: 0.7613 - val_loss: 2.3254 - val_acc: 0.1204
# Epoch 74/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.8221 - acc: 0.7783 - val_loss: 2.3726 - val_acc: 0.1214
# Epoch 75/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.8226 - acc: 0.7792 - val_loss: 2.3412 - val_acc: 0.1594
# Epoch 76/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8294 - acc: 0.7724 - val_loss: 2.3393 - val_acc: 0.1280
# Epoch 77/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8254 - acc: 0.7743 - val_loss: 2.3911 - val_acc: 0.1011
# Epoch 78/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8083 - acc: 0.7822 - val_loss: 2.3558 - val_acc: 0.1453
# Epoch 79/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.8093 - acc: 0.7803 - val_loss: 2.3302 - val_acc: 0.1472
# Epoch 80/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7983 - acc: 0.7866 - val_loss: 2.2960 - val_acc: 0.1715
# Epoch 81/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7953 - acc: 0.7832 - val_loss: 2.3154 - val_acc: 0.1487
# Epoch 82/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7959 - acc: 0.7841 - val_loss: 2.3407 - val_acc: 0.1116
# Epoch 83/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.7893 - acc: 0.7839 - val_loss: 2.3747 - val_acc: 0.1571
# Epoch 84/100
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.7778 - acc: 0.7939 - val_loss: 2.3989 - val_acc: 0.1023
# Epoch 85/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7835 - acc: 0.7937 - val_loss: 2.3454 - val_acc: 0.1750
# Epoch 86/100
# 10000/10000 [==============================] - 1s 56us/step - loss: 0.7716 - acc: 0.7906 - val_loss: 2.4045 - val_acc: 0.1273
# Epoch 87/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7804 - acc: 0.7880 - val_loss: 2.3306 - val_acc: 0.1428
# Epoch 88/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7596 - acc: 0.7941 - val_loss: 2.2495 - val_acc: 0.1518
# Epoch 89/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7672 - acc: 0.7995 - val_loss: 2.4568 - val_acc: 0.1106
# Epoch 90/100
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.7468 - acc: 0.7954 - val_loss: 2.3089 - val_acc: 0.1694
# Epoch 91/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.7568 - acc: 0.7984 - val_loss: 2.2810 - val_acc: 0.1521
# Epoch 92/100
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.7458 - acc: 0.7994 - val_loss: 2.2690 - val_acc: 0.1611
# Epoch 93/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.7453 - acc: 0.8010 - val_loss: 2.3232 - val_acc: 0.1661
# Epoch 94/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7476 - acc: 0.7997 - val_loss: 2.3208 - val_acc: 0.1199
# Epoch 95/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.7379 - acc: 0.8000 - val_loss: 2.3747 - val_acc: 0.1740
# Epoch 96/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7346 - acc: 0.8108 - val_loss: 2.2439 - val_acc: 0.2183
# Epoch 97/100
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7249 - acc: 0.8096 - val_loss: 2.2704 - val_acc: 0.2064
# Epoch 98/100
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.7260 - acc: 0.8124 - val_loss: 2.5193 - val_acc: 0.1143
# Epoch 99/100
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.7235 - acc: 0.8129 - val_loss: 2.4107 - val_acc: 0.1381
# Epoch 100/100
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.7102 - acc: 0.8197 - val_loss: 2.2806 - val_acc: 0.1442
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/120
# 10000/10000 [==============================] - 1s 69us/step - loss: 2.2208 - acc: 0.1868 - val_loss: 2.3020 - val_acc: 0.1100
# Epoch 2/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 2.0083 - acc: 0.2926 - val_loss: 2.3018 - val_acc: 0.1142
# Epoch 3/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.9072 - acc: 0.3365 - val_loss: 2.3017 - val_acc: 0.1113
# Epoch 4/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.8373 - acc: 0.3663 - val_loss: 2.3016 - val_acc: 0.1667
# Epoch 5/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.7839 - acc: 0.3894 - val_loss: 2.3015 - val_acc: 0.1252
# Epoch 6/120
# 10000/10000 [==============================] - 1s 64us/step - loss: 1.7401 - acc: 0.4038 - val_loss: 2.3013 - val_acc: 0.1559
# Epoch 7/120
# 10000/10000 [==============================] - 1s 63us/step - loss: 1.7037 - acc: 0.4209 - val_loss: 2.3011 - val_acc: 0.1459
# Epoch 8/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.6739 - acc: 0.4319 - val_loss: 2.3010 - val_acc: 0.1237
# Epoch 9/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.6453 - acc: 0.4439 - val_loss: 2.3009 - val_acc: 0.1220
# Epoch 10/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.6193 - acc: 0.4506 - val_loss: 2.3007 - val_acc: 0.1177
# Epoch 11/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.5951 - acc: 0.4627 - val_loss: 2.3007 - val_acc: 0.1118
# Epoch 12/120
# 10000/10000 [==============================] - 1s 63us/step - loss: 1.5723 - acc: 0.4744 - val_loss: 2.3006 - val_acc: 0.1064
# Epoch 13/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.5524 - acc: 0.4817 - val_loss: 2.3005 - val_acc: 0.1176
# Epoch 14/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.5332 - acc: 0.4877 - val_loss: 2.3004 - val_acc: 0.1047
# Epoch 15/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.5154 - acc: 0.4948 - val_loss: 2.3003 - val_acc: 0.1073
# Epoch 16/120
# 10000/10000 [==============================] - 1s 62us/step - loss: 1.4995 - acc: 0.5015 - val_loss: 2.3003 - val_acc: 0.1140
# Epoch 17/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4812 - acc: 0.5096 - val_loss: 2.3002 - val_acc: 0.1125
# Epoch 18/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.4683 - acc: 0.5143 - val_loss: 2.3001 - val_acc: 0.1162
# Epoch 19/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.4518 - acc: 0.5202 - val_loss: 2.3001 - val_acc: 0.1133
# Epoch 20/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4349 - acc: 0.5310 - val_loss: 2.3001 - val_acc: 0.1082
# Epoch 21/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.4225 - acc: 0.5364 - val_loss: 2.3001 - val_acc: 0.1156
# Epoch 22/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.4081 - acc: 0.5399 - val_loss: 2.3001 - val_acc: 0.1047
# Epoch 23/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.3952 - acc: 0.5471 - val_loss: 2.3003 - val_acc: 0.1159
# Epoch 24/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.3815 - acc: 0.5519 - val_loss: 2.3003 - val_acc: 0.1061
# Epoch 25/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.3705 - acc: 0.5571 - val_loss: 2.3005 - val_acc: 0.1161
# Epoch 26/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.3574 - acc: 0.5652 - val_loss: 2.3001 - val_acc: 0.1095
# Epoch 27/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.3450 - acc: 0.5714 - val_loss: 2.3005 - val_acc: 0.1120
# Epoch 28/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.3336 - acc: 0.5742 - val_loss: 2.3005 - val_acc: 0.1041
# Epoch 29/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.3248 - acc: 0.5740 - val_loss: 2.3009 - val_acc: 0.1148
# Epoch 30/120
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.3136 - acc: 0.5799 - val_loss: 2.3010 - val_acc: 0.1049
# Epoch 31/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.3019 - acc: 0.5920 - val_loss: 2.3010 - val_acc: 0.1115
# Epoch 32/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.2954 - acc: 0.5908 - val_loss: 2.3014 - val_acc: 0.1037
# Epoch 33/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.2828 - acc: 0.5936 - val_loss: 2.3017 - val_acc: 0.1126
# Epoch 34/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.2745 - acc: 0.6023 - val_loss: 2.3020 - val_acc: 0.1061
# Epoch 35/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.2649 - acc: 0.6038 - val_loss: 2.3024 - val_acc: 0.1073
# Epoch 36/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.2519 - acc: 0.6137 - val_loss: 2.3022 - val_acc: 0.1067
# Epoch 37/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.2472 - acc: 0.6155 - val_loss: 2.3028 - val_acc: 0.1149
# Epoch 38/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.2389 - acc: 0.6161 - val_loss: 2.3026 - val_acc: 0.1043
# Epoch 39/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.2249 - acc: 0.6253 - val_loss: 2.3033 - val_acc: 0.1034
# Epoch 40/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.2199 - acc: 0.6254 - val_loss: 2.3038 - val_acc: 0.1088
# Epoch 41/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.2065 - acc: 0.6296 - val_loss: 2.3048 - val_acc: 0.1061
# Epoch 42/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.1975 - acc: 0.6372 - val_loss: 2.3043 - val_acc: 0.1116
# Epoch 43/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.1924 - acc: 0.6391 - val_loss: 2.3056 - val_acc: 0.1058
# Epoch 44/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.1854 - acc: 0.6420 - val_loss: 2.3052 - val_acc: 0.1173
# Epoch 45/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.1728 - acc: 0.6487 - val_loss: 2.3064 - val_acc: 0.1091
# Epoch 46/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.1682 - acc: 0.6523 - val_loss: 2.3065 - val_acc: 0.1160
# Epoch 47/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.1598 - acc: 0.6523 - val_loss: 2.3085 - val_acc: 0.1201
# Epoch 48/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.1501 - acc: 0.6569 - val_loss: 2.3069 - val_acc: 0.1164
# Epoch 49/120
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.1442 - acc: 0.6578 - val_loss: 2.3090 - val_acc: 0.1215
# Epoch 50/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.1315 - acc: 0.6653 - val_loss: 2.3067 - val_acc: 0.1125
# Epoch 51/120
# 10000/10000 [==============================] - 1s 61us/step - loss: 1.1272 - acc: 0.6680 - val_loss: 2.3097 - val_acc: 0.1195
# Epoch 52/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.1214 - acc: 0.6687 - val_loss: 2.3102 - val_acc: 0.1064
# Epoch 53/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.1156 - acc: 0.6716 - val_loss: 2.3096 - val_acc: 0.1269
# Epoch 54/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.1086 - acc: 0.6770 - val_loss: 2.3136 - val_acc: 0.1124
# Epoch 55/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.1016 - acc: 0.6809 - val_loss: 2.3132 - val_acc: 0.1200
# Epoch 56/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.0939 - acc: 0.6814 - val_loss: 2.3129 - val_acc: 0.1070
# Epoch 57/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0867 - acc: 0.6854 - val_loss: 2.3163 - val_acc: 0.1226
# Epoch 58/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0803 - acc: 0.6887 - val_loss: 2.3139 - val_acc: 0.1073
# Epoch 59/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0748 - acc: 0.6931 - val_loss: 2.3162 - val_acc: 0.1207
# Epoch 60/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.0670 - acc: 0.6917 - val_loss: 2.3141 - val_acc: 0.1143
# Epoch 61/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.0638 - acc: 0.6947 - val_loss: 2.3127 - val_acc: 0.1221
# Epoch 62/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.0572 - acc: 0.6959 - val_loss: 2.3192 - val_acc: 0.1193
# Epoch 63/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0497 - acc: 0.7025 - val_loss: 2.3168 - val_acc: 0.1225
# Epoch 64/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.0460 - acc: 0.7044 - val_loss: 2.3196 - val_acc: 0.1116
# Epoch 65/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.0367 - acc: 0.7122 - val_loss: 2.3165 - val_acc: 0.1201
# Epoch 66/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 1.0317 - acc: 0.7117 - val_loss: 2.3194 - val_acc: 0.1330
# Epoch 67/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 1.0243 - acc: 0.7166 - val_loss: 2.3169 - val_acc: 0.1242
# Epoch 68/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.0185 - acc: 0.7154 - val_loss: 2.3205 - val_acc: 0.1171
# Epoch 69/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 1.0136 - acc: 0.7193 - val_loss: 2.3126 - val_acc: 0.1354
# Epoch 70/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 1.0100 - acc: 0.7211 - val_loss: 2.3247 - val_acc: 0.1142
# Epoch 71/120
# 10000/10000 [==============================] - 1s 63us/step - loss: 1.0036 - acc: 0.7221 - val_loss: 2.3180 - val_acc: 0.1177
# Epoch 72/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.9995 - acc: 0.7202 - val_loss: 2.3182 - val_acc: 0.1409
# Epoch 73/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9943 - acc: 0.7261 - val_loss: 2.3216 - val_acc: 0.1232
# Epoch 74/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9874 - acc: 0.7275 - val_loss: 2.3173 - val_acc: 0.1355
# Epoch 75/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9822 - acc: 0.7328 - val_loss: 2.3241 - val_acc: 0.1228
# Epoch 76/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9778 - acc: 0.7321 - val_loss: 2.3165 - val_acc: 0.1409
# Epoch 77/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9754 - acc: 0.7355 - val_loss: 2.3199 - val_acc: 0.1375
# Epoch 78/120
# 10000/10000 [==============================] - 1s 61us/step - loss: 0.9669 - acc: 0.7386 - val_loss: 2.3119 - val_acc: 0.1206
# Epoch 79/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9639 - acc: 0.7377 - val_loss: 2.3114 - val_acc: 0.1754
# Epoch 80/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.9577 - acc: 0.7448 - val_loss: 2.3152 - val_acc: 0.1231
# Epoch 81/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9548 - acc: 0.7413 - val_loss: 2.3016 - val_acc: 0.1615
# Epoch 82/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9486 - acc: 0.7476 - val_loss: 2.3153 - val_acc: 0.1479
# Epoch 83/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.9447 - acc: 0.7482 - val_loss: 2.3051 - val_acc: 0.1476
# Epoch 84/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9407 - acc: 0.7479 - val_loss: 2.3017 - val_acc: 0.1767
# Epoch 85/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.9342 - acc: 0.7514 - val_loss: 2.3085 - val_acc: 0.1307
# Epoch 86/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9270 - acc: 0.7557 - val_loss: 2.2894 - val_acc: 0.1957
# Epoch 87/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9251 - acc: 0.7596 - val_loss: 2.3219 - val_acc: 0.1243
# Epoch 88/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9209 - acc: 0.7554 - val_loss: 2.2794 - val_acc: 0.1841
# Epoch 89/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.9169 - acc: 0.7634 - val_loss: 2.3162 - val_acc: 0.1495
# Epoch 90/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9129 - acc: 0.7666 - val_loss: 2.3030 - val_acc: 0.1883
# Epoch 91/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.9062 - acc: 0.7679 - val_loss: 2.2578 - val_acc: 0.1495
# Epoch 92/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.9051 - acc: 0.7675 - val_loss: 2.2728 - val_acc: 0.1990
# Epoch 93/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8946 - acc: 0.7721 - val_loss: 2.2644 - val_acc: 0.1569
# Epoch 94/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8918 - acc: 0.7713 - val_loss: 2.2820 - val_acc: 0.1705
# Epoch 95/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8905 - acc: 0.7686 - val_loss: 2.2284 - val_acc: 0.2134
# Epoch 96/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8827 - acc: 0.7768 - val_loss: 2.2477 - val_acc: 0.1533
# Epoch 97/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8795 - acc: 0.7785 - val_loss: 2.2719 - val_acc: 0.2107
# Epoch 98/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.8735 - acc: 0.7796 - val_loss: 2.1977 - val_acc: 0.1958
# Epoch 99/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.8736 - acc: 0.7805 - val_loss: 2.2406 - val_acc: 0.2093
# Epoch 100/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.8698 - acc: 0.7818 - val_loss: 2.2392 - val_acc: 0.1527
# Epoch 101/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8688 - acc: 0.7757 - val_loss: 2.2268 - val_acc: 0.1830
# Epoch 102/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8653 - acc: 0.7806 - val_loss: 2.2069 - val_acc: 0.2143
# Epoch 103/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.8553 - acc: 0.7892 - val_loss: 2.1680 - val_acc: 0.1781
# Epoch 104/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8549 - acc: 0.7907 - val_loss: 2.2034 - val_acc: 0.2272
# Epoch 105/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.8470 - acc: 0.7919 - val_loss: 2.1770 - val_acc: 0.1774
# Epoch 106/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8436 - acc: 0.7925 - val_loss: 2.2352 - val_acc: 0.2140
# Epoch 107/120
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.8432 - acc: 0.7911 - val_loss: 2.1569 - val_acc: 0.2254
# Epoch 108/120
# 10000/10000 [==============================] - 1s 57us/step - loss: 0.8376 - acc: 0.7898 - val_loss: 2.1760 - val_acc: 0.2109
# Epoch 109/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.8362 - acc: 0.7941 - val_loss: 2.1559 - val_acc: 0.2196
# Epoch 110/120
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.8295 - acc: 0.7956 - val_loss: 2.0723 - val_acc: 0.2597
# Epoch 111/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8266 - acc: 0.8006 - val_loss: 2.1724 - val_acc: 0.2408
# Epoch 112/120
# 10000/10000 [==============================] - 1s 63us/step - loss: 0.8187 - acc: 0.8011 - val_loss: 2.0232 - val_acc: 0.2835
# Epoch 113/120
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.8197 - acc: 0.8019 - val_loss: 2.2054 - val_acc: 0.2491
# Epoch 114/120
# 10000/10000 [==============================] - 1s 66us/step - loss: 0.8166 - acc: 0.8041 - val_loss: 2.0696 - val_acc: 0.2239
# Epoch 115/120
# 10000/10000 [==============================] - 1s 64us/step - loss: 0.8090 - acc: 0.8084 - val_loss: 2.0697 - val_acc: 0.2689
# Epoch 116/120
# 10000/10000 [==============================] - 1s 62us/step - loss: 0.8089 - acc: 0.8050 - val_loss: 2.0676 - val_acc: 0.2411
# Epoch 117/120
# 10000/10000 [==============================] - 1s 59us/step - loss: 0.8074 - acc: 0.8070 - val_loss: 2.0751 - val_acc: 0.2602
# Epoch 118/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.8053 - acc: 0.8088 - val_loss: 2.0500 - val_acc: 0.2623
# Epoch 119/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7994 - acc: 0.8131 - val_loss: 1.9956 - val_acc: 0.2995
# Epoch 120/120
# 10000/10000 [==============================] - 1s 58us/step - loss: 0.7924 - acc: 0.8146 - val_loss: 2.0550 - val_acc: 0.2481

# %%
def get_aspect(ax=None):  # used to compute rotation of text here under
    if ax is None:
        ax = plt.gca()
    fig = ax.figure

    ll, ur = ax.get_position() * fig.get_size_inches()
    width, height = ur - ll
    axes_ratio = height / width
    aspect = axes_ratio / ax.get_data_ratio()

    return aspect

# %%
mpld3.disable_notebook()
matplotlib.rcParams.update({'font.size': 18})

lrs = [3**-2,3**-3,3**-4, 3**-5]
lrs_text = ['lr = $3^{-2}$', 'lr = $3^{-3}$', 'lr = $3^{-4}$', 'lr = $3^{-5}$']

results = load_results()
plt.figure()
plt.ylim([0,1])
plt.xlim([0,100])

for i,lr in enumerate(lrs):
    ladc_dense0 = np.array(results[lr]['ladc'])[:,0]
    
    plt.plot(range(len(ladc_dense0)),ladc_dense0)
    
    x_coord = 50+5*i
    diff = 30
    angle = m.atan((ladc_dense0[x_coord+diff]-ladc_dense0[x_coord])/diff*get_aspect())*180/m.pi
    
    plt.annotate(lrs_text[i], xy=(x_coord, ladc_dense0[x_coord]), xycoords='data', color = 'C'+str(i), size = 20,
                 rotation = angle+5, rotation_mode='anchor',
                 xytext = (0,5), textcoords = 'offset points')

plt.xlabel('Epoch')
plt.ylabel('Cosine distance')

plt.savefig('figures/cifar_layer_rotations_newmodel.png',format='png', dpi=200, bbox_inches="tight")

# %%
lrs = [3**-2,3**-3,3**-4, 3**-5]

results = load_results()
test_performances = []
train_performances = []
for lr in lrs:
    test_performances.append(results[lr]['history']['history']['val_acc'][-1])
    train_performances.append(results[lr]['history']['history']['acc'][-1])
print(test_performances)
print()
print(train_performances)
# Out:
# [0.1281, 0.16130000107288361, 0.1441999988079071, 0.2481000011444092]
#
# [0.8322999977111817, 0.9329000019073487, 0.8197000052452087, 0.8145999985694885]

# %%
lrs = [3**-2,3**-3,3**-4, 3**-5]

results = load_results()
model = get_model()

mpld3.disable_notebook()
nb_neurons = 5
neurons_per_line = nb_neurons
f, axes = plt.subplots(len(lrs), nb_neurons, 
                       figsize = (nb_neurons*3,len(lrs)*3))
for i,lr in enumerate(lrs):
    model.load_weights('saved_weights_cifar_newmodel/'+str(round(lr,6))[2:]+'.h5')
    
    weights = model.get_weights()[0]
    visualize_1stlayer_weights(weights,nb_neurons = nb_neurons, neuron_indices = range(5,10),
                               neurons_per_line = neurons_per_line, axes = axes[i])
    
    pad = -160
    axes[i,-1].annotate(' Train: '+str(round(results[lr]['history']['history']['acc'][-1]*100,2))+'%'+
                        '\n Test: '+str(round(results[lr]['history']['history']['val_acc'][-1]*100,2))+'%', 
                        xy=(0., 0.5), xytext=(-axes[i,-1].yaxis.labelpad - pad, 0.), 
                xycoords=axes[i,-1].yaxis.label, textcoords='offset points', 
                size=25, ha='left', va='center',rotation=0)

plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=-0.3)

plt.savefig('figures/cifar_features_visualization_newmodel.png',format='png', dpi=200, bbox_inches="tight")

f, axes = plt.subplots(1, nb_neurons, 
                       figsize = (nb_neurons*3,3))
    
model.load_weights('saved_weights_cifar_newmodel/cifar_initial_weights.h5')
weights = model.get_weights()[0]
visualize_1stlayer_weights(weights,nb_neurons = nb_neurons, neuron_indices = range(5,10),
                           neurons_per_line = neurons_per_line, axes = axes)

pad = 10
axes[0].annotate('initialization', xy=(0, 0.5), xytext=(-axes[0].yaxis.labelpad - pad, 0),
            xycoords=axes[0].yaxis.label, textcoords='offset points',
            size=25, ha='right', va='center',rotation=90)

plt.subplots_adjust(wspace=0.3)
# plt.subplots_adjust(hspace=-0.3)


plt.savefig('figures/cifar_initialization_visualization_newmodel.png',format='png', dpi=200, bbox_inches="tight")
# Out:
# c:\Users\rjtdu\OneDrive\Desktop\LayerRotation\layer-rotation-paper-experiments\MNIST - 1st layer feature visualization\feature_visualization.py:27: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   kernel = weights[index].reshape((28,28))

# %%
# ----------------------------------
# 8. Metrics: Accuracy, Precision, Recall, F1, AUC
# ----------------------------------

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
model = get_model()
model.load_weights('saved_weights_cifar_newmodel/'+str(round(lr,6))[2:]+'.h5')
y_pred = model.predict(x_test)
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)


accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='macro')
recall = recall_score(y_true, y_pred_classes, average='macro')
f1 = f1_score(y_true, y_pred_classes, average='macro')
auc = roc_auc_score(y_test, y_pred, multi_class='ovr')


print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("AUC:", auc)
# Out:
# Accuracy: 0.2481
# Precision: 0.4378485103954188
# Recall: 0.2481
# F1 Score: 0.22756746579348572
# AUC: 0.7930574777777778
